# %% [markdown]
# # DIABOLO

# %%
# Import all libraries needed for the tutorial

# General syntax to import specific functions in a library: 
##from (library) import (specific library function)
#from  pandas import DataFrame, read_csv

# General syntax to import a library but no functions: 
##import (library) as (give the library a nickname/alias)

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

#vous pouvez modifier cette option à votre guise
pd.options.display.max_rows = 10

                   
Location_csv = 'd:\diabolo.csv'
xnames=['ALLURE','DATE_COURSE','CO_DISTANCE','CO_NB','CO_PRIX','HIPPO','IDCOURSE','IDPARTCIPANT','PAR_age','PAR_ARRIVE',
'PAR_CARRIERE','PAR_CARRIERE_Q','PAR_CLASSE_AGE','PAR_CORDE','PAR_COTEDER','PAR_ENT_ECART_GAGNANT','PAR_ENT_RAPPORT_GAGNANT_M',
'PAR_ENT_RAPPORT_GANGANT','PAR_ENT_REU_PLACE','PAR_ENT_REUSSITE_GAGNE','PAR_ENT_VICTOIRE','PAR_GAIN','pAR_JOC_ECART_GAGNANT',
'PAR_JOC_ECART_PLACE','PAR_JOC_NB_COURSE','PAR_JOC_PLACE_3P','pAR_JOC_RAPPORT_GAGNANT_M','PAR_JOC_REU_PLACE','pAR_JOC_REUSSITE_GAGNE',
'pAR_JOC_VICTOIRE','PAR_NP','PAR_NUM','PAR_PLACE','PAR_PLACE_Q','PAR_REUSSITE_3P','PAR_REUSSITE_GAGNE','PAR_REUSSITE_QUINTE','PAR_RUESSITE_PLACE','autostart','cendre','grande_piste','sable_fibre','dirt','FIN_ligne']
    
df=pd.read_csv (Location_csv, sep=';',names=xnames,nrows=10000,skipinitialspace=True,encoding='Latin-1')

df=df.groupby('ALLURE')     
df=df.get_group(1) 

#Suppression de la collone TROT
df.drop(["ALLURE"], axis=1, inplace=True)

#Suppression de la collone TROT
df.drop(["FIN_ligne"], axis=1, inplace=True)

#Suppression de la collone TROT
df.drop(["DATE_COURSE"], axis=1, inplace=True)

#Suppression de la collone TROT
df.drop(["IDPARTCIPANT"], axis=1, inplace=True)

#Suppression de la collone TROT
df.drop(["HIPPO"], axis=1, inplace=True)

#Suppression de la collone TROT
df.drop(["IDCOURSE"], axis=1, inplace=True)

#Suppression de la collone TROT
df.drop(["PAR_CORDE"], axis=1, inplace=True)

#Suppression de la collone TROT
df.drop(["CO_DISTANCE"], axis=1, inplace=True)

#Suppression de la collone TROT
df.drop(["CO_NB"], axis=1, inplace=True)

#Suppression de la collone TROT
#df.drop(["CO_PRIX"], axis=1, inplace=True)
#Suppression de la collone TROT

df.drop(["PAR_age"], axis=1, inplace=True)
df.drop(["PAR_ENT_RAPPORT_GANGANT"], axis=1, inplace=True)

df.drop(["sable_fibre"], axis=1, inplace=True)
df.drop(["dirt"], axis=1, inplace=True)


#xnames=['CO_DISTANCE','CO_NB','CO_PRIX','HIPPO','IDCOURSE','PAR_age','PAR_ARRIVE',
#'PAR_CARRIERE','PAR_CARRIERE_Q','PAR_CLASSE_AGE','PAR_CORDE','PAR_COTEDER','PAR_ENT_ECART_GAGNANT','PAR_ENT_RAPPORT_GAGNANT_M',
#'PAR_ENT_RAPPORT_GANGANT','PAR_ENT_REU_PLACE','PAR_ENT_REUSSITE_GAGNE','PAR_ENT_VICTOIRE','PAR_GAIN','pAR_JOC_ECART_GAGNANT',
#'PAR_JOC_ECART_PLACE','PAR_JOC_NB_COURSE','PAR_JOC_PLACE_3P','pAR_JOC_RAPPORT_GAGNANT_M','PAR_JOC_REU_PLACE','pAR_JOC_REUSSITE_GAGNE',
#'pAR_JOC_VICTOIRE','PAR_NP','PAR_PLACE','PAR_PLACE_Q','PAR_REUSSITE_3P','PAR_REUSSITE_GAGNE','PAR_REUSSITE_QUINTE','PAR_RUESSITE_PLACE','autostart','cendre','grande_piste','sable_fibre','dirt']
   
#Transformer une colonne en un index dans un dataframe
#df = df.set_index('IDPARTCIPANT')

#affichage des premiere lignes du jeu de données
df.head()
# Out:
#     CO_PRIX  PAR_ARRIVE  PAR_CARRIERE  PAR_CARRIERE_Q  PAR_CLASSE_AGE  \
# 9     90000          99            41               5           44456
# 10    90000           4            58               3           34229
# 11    90000           2            41               9           40630
# 12    90000           1            64               2           39671
# 13    90000          99            10               1           48270
#
#     PAR_COTEDER  PAR_ENT_ECART_GAGNANT  PAR_ENT_RAPPORT_GAGNANT_M  \
# 9            32                      6                       8.96
# 10            8                     41                       6.85
# 11           36                      0                       8.72
# 12            6                      0                       0.00
# 13           10                      0                       3.33
#
#     PAR_ENT_REU_PLACE  PAR_ENT_REUSSITE_GAGNE      ...       PAR_NUM  \
# 9                0.21                    0.06      ...             1
# 10               0.12                    0.04      ...             2
# 11               0.27                    0.10      ...             3
# 12               0.20                    0.00      ...             4
# 13               0.46                    0.21      ...             5
#
#     PAR_PLACE  PAR_PLACE_Q  PAR_REUSSITE_3P  PAR_REUSSITE_GAGNE  \
# 9           7            0         0.292683            0.121951
# 10         14            2         0.396552            0.155172
# 11         11            4         0.585366            0.317073
# 12         18            0         0.500000            0.218750
# 13          2            0         0.800000            0.600000
#
#     PAR_REUSSITE_QUINTE  PAR_RUESSITE_PLACE  autostart  cendre  grande_piste
# 9               0.00000            0.170732          1       1             1
# 10              0.00000            0.241379          1       1             1
# 11              0.04878            0.268293          1       1             1
# 12              0.03125            0.281250          1       1             1
# 13              0.00000            0.200000          1       1             1
#
# [5 rows x 31 columns]

# %%
# trvail sur les courses de trot (allure=1)
print(df.shape)
# Out:
# (5473, 31)

# %%
#enumeration des colonnes
df.columns
# Out:
# Index(['CO_PRIX', 'PAR_ARRIVE', 'PAR_CARRIERE', 'PAR_CARRIERE_Q',
#        'PAR_CLASSE_AGE', 'PAR_COTEDER', 'PAR_ENT_ECART_GAGNANT',
#        'PAR_ENT_RAPPORT_GAGNANT_M', 'PAR_ENT_REU_PLACE',
#        'PAR_ENT_REUSSITE_GAGNE', 'PAR_ENT_VICTOIRE', 'PAR_GAIN',
#        'pAR_JOC_ECART_GAGNANT', 'PAR_JOC_ECART_PLACE', 'PAR_JOC_NB_COURSE',
#        'PAR_JOC_PLACE_3P', 'pAR_JOC_RAPPORT_GAGNANT_M', 'PAR_JOC_REU_PLACE',
#        'pAR_JOC_REUSSITE_GAGNE', 'pAR_JOC_VICTOIRE', 'PAR_NP', 'PAR_NUM',
#        'PAR_PLACE', 'PAR_PLACE_Q', 'PAR_REUSSITE_3P', 'PAR_REUSSITE_GAGNE',
#        'PAR_REUSSITE_QUINTE', 'PAR_RUESSITE_PLACE', 'autostart', 'cendre',
#        'grande_piste'],
#       dtype='object')

# %%
#gagnant
#sélection des chevaux dans les 5 premiers


df_gagnant = df

# %%
df_gagnant=df_gagnant[df_gagnant.PAR_GAIN >0]
df_gagnant
# Out:
#       CO_PRIX  PAR_ARRIVE  PAR_CARRIERE  PAR_CARRIERE_Q  PAR_CLASSE_AGE  \
# 9       90000          99            41               5           44456
# 10      90000           4            58               3           34229
# 11      90000           2            41               9           40630
# 12      90000           1            64               2           39671
# 13      90000          99            10               1           48270
# ...       ...         ...           ...             ...             ...
# 9995    17000          99            10               0              27
# 9996    17000          99            49               0            1492
# 9997    17000           4            33               0            1915
# 9998    17000          99            22               0            2110
# 9999    21000           5            90               1           12887
#
#       PAR_COTEDER  PAR_ENT_ECART_GAGNANT  PAR_ENT_RAPPORT_GAGNANT_M  \
# 9              32                      6                       8.96
# 10              8                     41                       6.85
# 11             36                      0                       8.72
# 12              6                      0                       0.00
# 13             10                      0                       3.33
# ...           ...                    ...                        ...
# 9995            0                     21                      10.40
# 9996            7                     47                      17.35
# 9997          173                      5                      18.10
# 9998           28                     36                      15.48
# 9999            8                      0                       0.00
#
#       PAR_ENT_REU_PLACE  PAR_ENT_REUSSITE_GAGNE      ...       PAR_NUM  \
# 9                  0.21                    0.06      ...             1
# 10                 0.12                    0.04      ...             2
# 11                 0.27                    0.10      ...             3
# 12                 0.20                    0.00      ...             4
# 13                 0.46                    0.21      ...             5
# ...                 ...                     ...      ...           ...
# 9995               0.10                    0.02      ...            11
# 9996               0.09                    0.05      ...            12
# 9997               0.15                    0.05      ...            13
# 9998               0.18                    0.02      ...            14
# 9999               0.00                    0.00      ...             1
#
#       PAR_PLACE  PAR_PLACE_Q  PAR_REUSSITE_3P  PAR_REUSSITE_GAGNE  \
# 9             7            0         0.292683            0.121951
# 10           14            2         0.396552            0.155172
# 11           11            4         0.585366            0.317073
# 12           18            0         0.500000            0.218750
# 13            2            0         0.800000            0.600000
# ...         ...          ...              ...                 ...
# 9995          0            0         0.000000            0.000000
# 9996          7            0         0.244898            0.102041
# 9997          4            0         0.151515            0.030303
# 9998          5            0         0.227273            0.000000
# 9999         14            0         0.277778            0.122222
#
#       PAR_REUSSITE_QUINTE  PAR_RUESSITE_PLACE  autostart  cendre  grande_piste
# 9                 0.00000            0.170732          1       1             1
# 10                0.00000            0.241379          1       1             1
# 11                0.04878            0.268293          1       1             1
# 12                0.03125            0.281250          1       1             1
# 13                0.00000            0.200000          1       1             1
# ...                   ...                 ...        ...     ...           ...
# 9995              0.00000            0.000000          1       0             0
# 9996              0.00000            0.142857          1       0             0
# 9997              0.00000            0.121212          1       0             0
# 9998              0.00000            0.227273          1       0             0
# 9999              0.00000            0.155556          1       0             0
#
# [4444 rows x 31 columns]

# %%
df_gagnant.columns
# Out:
# Index(['CO_PRIX', 'PAR_ARRIVE', 'PAR_CARRIERE', 'PAR_CARRIERE_Q',
#        'PAR_CLASSE_AGE', 'PAR_COTEDER', 'PAR_ENT_ECART_GAGNANT',
#        'PAR_ENT_RAPPORT_GAGNANT_M', 'PAR_ENT_REU_PLACE',
#        'PAR_ENT_REUSSITE_GAGNE', 'PAR_ENT_VICTOIRE', 'PAR_GAIN',
#        'pAR_JOC_ECART_GAGNANT', 'PAR_JOC_ECART_PLACE', 'PAR_JOC_NB_COURSE',
#        'PAR_JOC_PLACE_3P', 'pAR_JOC_RAPPORT_GAGNANT_M', 'PAR_JOC_REU_PLACE',
#        'pAR_JOC_REUSSITE_GAGNE', 'pAR_JOC_VICTOIRE', 'PAR_NP', 'PAR_NUM',
#        'PAR_PLACE', 'PAR_PLACE_Q', 'PAR_REUSSITE_3P', 'PAR_REUSSITE_GAGNE',
#        'PAR_REUSSITE_QUINTE', 'PAR_RUESSITE_PLACE', 'autostart', 'cendre',
#        'grande_piste'],
#       dtype='object')

# %%
pd.options.mode.chained_assignment = None


df_gagnant['SELECTION'] = (df_gagnant.PAR_ARRIVE<=3).astype(int)
df_gagnant
# Out:
#       CO_PRIX  PAR_ARRIVE  PAR_CARRIERE  PAR_CARRIERE_Q  PAR_CLASSE_AGE  \
# 9       90000          99            41               5           44456
# 10      90000           4            58               3           34229
# 11      90000           2            41               9           40630
# 12      90000           1            64               2           39671
# 13      90000          99            10               1           48270
# ...       ...         ...           ...             ...             ...
# 9995    17000          99            10               0              27
# 9996    17000          99            49               0            1492
# 9997    17000           4            33               0            1915
# 9998    17000          99            22               0            2110
# 9999    21000           5            90               1           12887
#
#       PAR_COTEDER  PAR_ENT_ECART_GAGNANT  PAR_ENT_RAPPORT_GAGNANT_M  \
# 9              32                      6                       8.96
# 10              8                     41                       6.85
# 11             36                      0                       8.72
# 12              6                      0                       0.00
# 13             10                      0                       3.33
# ...           ...                    ...                        ...
# 9995            0                     21                      10.40
# 9996            7                     47                      17.35
# 9997          173                      5                      18.10
# 9998           28                     36                      15.48
# 9999            8                      0                       0.00
#
#       PAR_ENT_REU_PLACE  PAR_ENT_REUSSITE_GAGNE    ...      PAR_PLACE  \
# 9                  0.21                    0.06    ...              7
# 10                 0.12                    0.04    ...             14
# 11                 0.27                    0.10    ...             11
# 12                 0.20                    0.00    ...             18
# 13                 0.46                    0.21    ...              2
# ...                 ...                     ...    ...            ...
# 9995               0.10                    0.02    ...              0
# 9996               0.09                    0.05    ...              7
# 9997               0.15                    0.05    ...              4
# 9998               0.18                    0.02    ...              5
# 9999               0.00                    0.00    ...             14
#
#       PAR_PLACE_Q  PAR_REUSSITE_3P  PAR_REUSSITE_GAGNE  PAR_REUSSITE_QUINTE  \
# 9               0         0.292683            0.121951              0.00000
# 10              2         0.396552            0.155172              0.00000
# 11              4         0.585366            0.317073              0.04878
# 12              0         0.500000            0.218750              0.03125
# 13              0         0.800000            0.600000              0.00000
# ...           ...              ...                 ...                  ...
# 9995            0         0.000000            0.000000              0.00000
# 9996            0         0.244898            0.102041              0.00000
# 9997            0         0.151515            0.030303              0.00000
# 9998            0         0.227273            0.000000              0.00000
# 9999            0         0.277778            0.122222              0.00000
#
#       PAR_RUESSITE_PLACE  autostart  cendre  grande_piste  SELECTION
# 9               0.170732          1       1             1          0
# 10              0.241379          1       1             1          0
# 11              0.268293          1       1             1          1
# 12              0.281250          1       1             1          1
# 13              0.200000          1       1             1          0
# ...                  ...        ...     ...           ...        ...
# 9995            0.000000          1       0             0          0
# 9996            0.142857          1       0             0          0
# 9997            0.121212          1       0             0          0
# 9998            0.227273          1       0             0          0
# 9999            0.155556          1       0             0          0
#
# [4444 rows x 32 columns]

# %%
df_gagnant.groupby('SELECTION').mean()
# Out:
#                 CO_PRIX  PAR_ARRIVE  PAR_CARRIERE  PAR_CARRIERE_Q  \
# SELECTION
# 0          25405.923011   81.744705     52.670864        1.200343
# 1          24710.381053    2.003158     48.040000        1.402105
#
#            PAR_CLASSE_AGE  PAR_COTEDER  PAR_ENT_ECART_GAGNANT  \
# SELECTION
# 0            18304.459073    47.730681               9.638523
# 1            29787.477895    15.771579               9.171579
#
#            PAR_ENT_RAPPORT_GAGNANT_M  PAR_ENT_REU_PLACE  \
# SELECTION
# 0                           9.022358           0.193970
# 1                           8.796705           0.243284
#
#            PAR_ENT_REUSSITE_GAGNE      ...        PAR_NUM  PAR_PLACE  \
# SELECTION                              ...
# 0                        0.060495      ...       7.915283   9.024900
# 1                        0.083674      ...       8.038947  10.084211
#
#            PAR_PLACE_Q  PAR_REUSSITE_3P  PAR_REUSSITE_GAGNE  \
# SELECTION
# 0             0.312250         0.258269            0.091498
# 1             0.411579         0.361194            0.141788
#
#            PAR_REUSSITE_QUINTE  PAR_RUESSITE_PLACE  autostart    cendre  \
# SELECTION
# 0                     0.001012            0.166771   0.322839  0.253864
# 1                     0.002667            0.219406   0.361053  0.252632
#
#            grande_piste
# SELECTION
# 0              0.216371
# 1              0.211579
#
# [2 rows x 31 columns]

# %%
#Suppression de la colonne PAR_ARRIVE
df_gagnant.drop(["PAR_ARRIVE"], axis=1, inplace=True)
df_gagnant
# Out:
#       CO_PRIX  PAR_CARRIERE  PAR_CARRIERE_Q  PAR_CLASSE_AGE  PAR_COTEDER  \
# 9       90000            41               5           44456           32
# 10      90000            58               3           34229            8
# 11      90000            41               9           40630           36
# 12      90000            64               2           39671            6
# 13      90000            10               1           48270           10
# ...       ...           ...             ...             ...          ...
# 9995    17000            10               0              27            0
# 9996    17000            49               0            1492            7
# 9997    17000            33               0            1915          173
# 9998    17000            22               0            2110           28
# 9999    21000            90               1           12887            8
#
#       PAR_ENT_ECART_GAGNANT  PAR_ENT_RAPPORT_GAGNANT_M  PAR_ENT_REU_PLACE  \
# 9                         6                       8.96               0.21
# 10                       41                       6.85               0.12
# 11                        0                       8.72               0.27
# 12                        0                       0.00               0.20
# 13                        0                       3.33               0.46
# ...                     ...                        ...                ...
# 9995                     21                      10.40               0.10
# 9996                     47                      17.35               0.09
# 9997                      5                      18.10               0.15
# 9998                     36                      15.48               0.18
# 9999                      0                       0.00               0.00
#
#       PAR_ENT_REUSSITE_GAGNE  PAR_ENT_VICTOIRE    ...      PAR_PLACE  \
# 9                       0.06                 9    ...              7
# 10                      0.04                 6    ...             14
# 11                      0.10                21    ...             11
# 12                      0.00                 0    ...             18
# 13                      0.21                80    ...              2
# ...                      ...               ...    ...            ...
# 9995                    0.02                 1    ...              0
# 9996                    0.05                 4    ...              7
# 9997                    0.05                 1    ...              4
# 9998                    0.02                 5    ...              5
# 9999                    0.00                 0    ...             14
#
#       PAR_PLACE_Q  PAR_REUSSITE_3P  PAR_REUSSITE_GAGNE  PAR_REUSSITE_QUINTE  \
# 9               0         0.292683            0.121951              0.00000
# 10              2         0.396552            0.155172              0.00000
# 11              4         0.585366            0.317073              0.04878
# 12              0         0.500000            0.218750              0.03125
# 13              0         0.800000            0.600000              0.00000
# ...           ...              ...                 ...                  ...
# 9995            0         0.000000            0.000000              0.00000
# 9996            0         0.244898            0.102041              0.00000
# 9997            0         0.151515            0.030303              0.00000
# 9998            0         0.227273            0.000000              0.00000
# 9999            0         0.277778            0.122222              0.00000
#
#       PAR_RUESSITE_PLACE  autostart  cendre  grande_piste  SELECTION
# 9               0.170732          1       1             1          0
# 10              0.241379          1       1             1          0
# 11              0.268293          1       1             1          1
# 12              0.281250          1       1             1          1
# 13              0.200000          1       1             1          0
# ...                  ...        ...     ...           ...        ...
# 9995            0.000000          1       0             0          0
# 9996            0.142857          1       0             0          0
# 9997            0.121212          1       0             0          0
# 9998            0.227273          1       0             0          0
# 9999            0.155556          1       0             0          0
#
# [4444 rows x 31 columns]

# %%
df_gagnant.groupby('SELECTION').mean()
# Out:
#                 CO_PRIX  PAR_CARRIERE  PAR_CARRIERE_Q  PAR_CLASSE_AGE  \
# SELECTION
# 0          25405.923011     52.670864        1.200343    18304.459073
# 1          24710.381053     48.040000        1.402105    29787.477895
#
#            PAR_COTEDER  PAR_ENT_ECART_GAGNANT  PAR_ENT_RAPPORT_GAGNANT_M  \
# SELECTION
# 0            47.730681               9.638523                   9.022358
# 1            15.771579               9.171579                   8.796705
#
#            PAR_ENT_REU_PLACE  PAR_ENT_REUSSITE_GAGNE  PAR_ENT_VICTOIRE  \
# SELECTION
# 0                   0.193970                0.060495         12.864625
# 1                   0.243284                0.083674         18.515789
#
#                ...        PAR_NUM  PAR_PLACE  PAR_PLACE_Q  PAR_REUSSITE_3P  \
# SELECTION      ...
# 0              ...       7.915283   9.024900     0.312250         0.258269
# 1              ...       8.038947  10.084211     0.411579         0.361194
#
#            PAR_REUSSITE_GAGNE  PAR_REUSSITE_QUINTE  PAR_RUESSITE_PLACE  \
# SELECTION
# 0                    0.091498             0.001012            0.166771
# 1                    0.141788             0.002667            0.219406
#
#            autostart    cendre  grande_piste
# SELECTION
# 0           0.322839  0.253864      0.216371
# 1           0.361053  0.252632      0.211579
#
# [2 rows x 30 columns]

# %%
# histogram of education
df_gagnant.PAR_REUSSITE_3P.hist()
plt.title('Reussite du cheval')
plt.xlabel('reussite du cheval')
plt.ylabel('occurence de cette reussite')
# Out:
# Text(0,0.5,'occurence de cette reussite')

# %%
df_gagnant.PAR_JOC_REU_PLACE.hist()
plt.title('Reussite du jockey')
plt.xlabel('reussite du jockey')
plt.ylabel('occurence de cette reussite')
# Out:
# Text(0,0.5,'occurence de cette reussite')

# %%
# La reussite du jockey n est pas la meme.


df_gagnant.PAR_ENT_REU_PLACE.hist()
plt.title('Reussite du jockey')
plt.xlabel('reussite du jockey')
plt.ylabel('occurence de cette reussite')
# Out:
# Text(0,0.5,'occurence de cette reussite')

# %%
#REGRESSESSION LINEAIRE MULTIVARIABLE

import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model
import sklearn

# %%
#df_gagnant['COEF'] = 1
#df_gagnant
data = np.matrix(df_gagnant)
data
X = data[:,0:29]
X
# Out:
# matrix([[  9.00000000e+04,   4.10000000e+01,   5.00000000e+00, ...,
#            1.70732000e-01,   1.00000000e+00,   1.00000000e+00],
#         [  9.00000000e+04,   5.80000000e+01,   3.00000000e+00, ...,
#            2.41379000e-01,   1.00000000e+00,   1.00000000e+00],
#         [  9.00000000e+04,   4.10000000e+01,   9.00000000e+00, ...,
#            2.68293000e-01,   1.00000000e+00,   1.00000000e+00],
#         ...,
#         [  1.70000000e+04,   3.30000000e+01,   0.00000000e+00, ...,
#            1.21212000e-01,   1.00000000e+00,   0.00000000e+00],
#         [  1.70000000e+04,   2.20000000e+01,   0.00000000e+00, ...,
#            2.27273000e-01,   1.00000000e+00,   0.00000000e+00],
#         [  2.10000000e+04,   9.00000000e+01,   1.00000000e+00, ...,
#            1.55556000e-01,   1.00000000e+00,   0.00000000e+00]])

# %%
y = data[:,30]
y
# Out:
# matrix([[ 0.],
#         [ 0.],
#         [ 1.],
#         ...,
#         [ 0.],
#         [ 0.],
#         [ 0.]])

# %%
from sklearn import preprocessing

normalized_X = preprocessing.normalize(X)
normalized_X
# Out:
# array([[  3.69008852e-01,   1.68104032e-04,   2.05004918e-05, ...,
#           7.00017992e-07,   4.10009835e-06,   4.10009835e-06],
#        [  3.96770643e-01,   2.55696636e-04,   1.32256881e-05, ...,
#           1.06413446e-06,   4.40856270e-06,   4.40856270e-06],
#        [  3.42172817e-01,   1.55878728e-04,   3.42172817e-05, ...,
#           1.02002857e-06,   3.80192019e-06,   3.80192019e-06],
#        ...,
#        [  9.06908595e-01,   1.76046963e-03,   0.00000000e+00, ...,
#           6.46636498e-06,   5.33475644e-05,   0.00000000e+00],
#        [  8.90176045e-01,   1.15199253e-03,   0.00000000e+00, ...,
#           1.19007635e-05,   5.23632968e-05,   0.00000000e+00],
#        [  1.98107059e-01,   8.49030253e-04,   9.43366948e-06, ...,
#           1.46746389e-06,   9.43366948e-06,   0.00000000e+00]])

# %%
standardized_X = preprocessing.scale(X)
standardized_X
# Out:
# array([[ 2.71617139, -0.35784566,  1.02801052, ..., -0.08275626,
#          1.42164486,  1.71557922],
#        [ 2.71617139,  0.21170989,  0.48069068, ...,  0.71912676,
#          1.42164486,  1.71557922],
#        [ 2.71617139, -0.35784566,  2.12265022, ...,  1.02461573,
#          1.42164486,  1.71557922],
#        ...,
#        [-0.34641815, -0.6258718 , -0.3402891 , ..., -0.64483599,
#          1.42164486, -0.58289351],
#        [-0.34641815, -0.99440775, -0.3402891 , ...,  0.55901576,
#          1.42164486, -0.58289351],
#        [-0.17860502,  1.28381446, -0.06662917, ..., -0.25501235,
#          1.42164486, -0.58289351]])

# %%
#Logistic Regression
from sklearn import metrics
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(X, y)
print(model)
# make predictions
expected = y
predicted = model.predict(X)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
# summarize the fit of the model
print(metrics.classification_report(expected, predicted))
print(metrics.confusion_matrix(expected, predicted))
# Out:
#              precision    recall  f1-score   support
#
#         0.0       0.79      1.00      0.88      3494
#         1.0       0.62      0.01      0.02       950
#
# avg / total       0.75      0.79      0.70      4444
#
# [[3488    6]
#  [ 940   10]]

# %%
#NAIVE BAYES
from sklearn import metrics
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model.fit(X, y)
print(model)
# make predictions
expected = y
predicted = model.predict(X)
# summarize the fit of the model
print(metrics.classification_report(expected, predicted))
print(metrics.confusion_matrix(expected, predicted))
# Out:
# GaussianNB(priors=None)
#              precision    recall  f1-score   support
#
#         0.0       0.79      0.93      0.86      3494
#         1.0       0.31      0.12      0.17       950
#
# avg / total       0.69      0.76      0.71      4444
#
# [[3245  249]
#  [ 837  113]]
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
#k-Nearest Neighbours
from sklearn import metrics
from sklearn.neighbors import KNeighborsClassifier
# fit a k-nearest neighbor model to the data
model = KNeighborsClassifier()
model.fit(X, y)
print(model)
# make predictions
expected = y
predicted = model.predict(X)
# summarize the fit of the model
print(metrics.classification_report(expected, predicted))
print(metrics.confusion_matrix(expected, predicted))
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#            weights='uniform')
#              precision    recall  f1-score   support
#
#         0.0       0.82      0.97      0.89      3494
#         1.0       0.65      0.21      0.31       950
#
# avg / total       0.78      0.81      0.76      4444
#
# [[3388  106]
#  [ 755  195]]
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().

# %%
#Decision Trees

from sklearn import metrics
from sklearn.tree import DecisionTreeClassifier
# fit a CART model to the data
model = DecisionTreeClassifier()
model.fit(X, y)
print(model)
# make predictions
expected = y
predicted = model.predict(X)
# summarize the fit of the model
print(metrics.classification_report(expected, predicted))
print(metrics.confusion_matrix(expected, predicted))
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')
#              precision    recall  f1-score   support
#
#         0.0       1.00      1.00      1.00      3494
#         1.0       1.00      1.00      1.00       950
#
# avg / total       1.00      1.00      1.00      4444
#
# [[3494    0]
#  [   0  950]]

# %%
#Support Vector Machines

from sklearn import metrics
from sklearn.svm import SVC
# fit a SVM model to the data
model = SVC()
model.fit(X, y)
print(model)
# make predictions
expected = y
predicted = model.predict(X)
# summarize the fit of the model
print(metrics.classification_report(expected, predicted))
print(metrics.confusion_matrix(expected, predicted))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
#              precision    recall  f1-score   support
#
#         0.0       1.00      1.00      1.00      3494
#         1.0       1.00      1.00      1.00       950
#
# avg / total       1.00      1.00      1.00      4444
#
# [[3494    0]
#  [   0  950]]

# %%
data = np.matrix(df_gagnant)
data

from sklearn.cross_validation import train_test_split

X_train,X_test,y_train,y_test=train_test_split(data,data,test_size=0.25,random_state=11)
y_test
# Out:
# matrix([[  2.00000000e+04,   6.00000000e+01,   0.00000000e+00, ...,
#            0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#         [  4.80000000e+04,   4.00000000e+01,   0.00000000e+00, ...,
#            1.00000000e+00,   1.00000000e+00,   0.00000000e+00],
#         [  2.30000000e+04,   1.60000000e+01,   0.00000000e+00, ...,
#            0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#         ...,
#         [  3.50000000e+04,   3.20000000e+01,   0.00000000e+00, ...,
#            1.00000000e+00,   1.00000000e+00,   0.00000000e+00],
#         [  7.50000000e+04,   9.70000000e+01,   6.00000000e+00, ...,
#            1.00000000e+00,   1.00000000e+00,   0.00000000e+00],
#         [  7.80000000e+04,   2.60000000e+01,   1.00000000e+00, ...,
#            1.00000000e+00,   1.00000000e+00,   0.00000000e+00]])

# %%
T=df_gagnant.drop(['SELECTION'], axis=1)
z=df_gagnant['SELECTION']

# %%
T_train,T_test,z_train,z_test=train_test_split(T,z,
test_size=0.2,random_state=11)

# %%
X_train
# Out:
# matrix([[  1.70000000e+04,   4.30000000e+01,   0.00000000e+00, ...,
#            0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#         [  5.00000000e+03,   2.40000000e+01,   0.00000000e+00, ...,
#            0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#         [  1.20000000e+05,   2.10000000e+01,   3.00000000e+00, ...,
#            1.00000000e+00,   1.00000000e+00,   0.00000000e+00],
#         ...,
#         [  2.20000000e+04,   1.10000000e+02,   2.00000000e+00, ...,
#            0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#         [  1.60000000e+04,   2.90000000e+01,   0.00000000e+00, ...,
#            0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#         [  1.20000000e+04,   9.80000000e+01,   0.00000000e+00, ...,
#            0.00000000e+00,   0.00000000e+00,   1.00000000e+00]])

# %%
from sklearn.linear_model import LogisticRegression
logit = LogisticRegression()
titan_logit=logit.fit(T_train, z_train)
# Erreur
titan_logit.score(T_test, z_test)
# Coefficients
titan_logit.coef_
# Out:
# array([[ -6.94959249e-06,  -8.53988237e-03,   1.11542953e-02,
#          -1.97322620e-07,  -3.60297346e-02,  -2.79896124e-03,
#          -4.55091942e-03,   7.40043535e-05,   6.76326974e-05,
#           4.37755782e-03,   9.73074426e-08,  -3.44920558e-03,
#          -1.14607827e-03,   5.14660608e-04,   1.91902450e-04,
#           4.36763165e-03,   3.40907678e-04,   1.19272213e-04,
#          -3.43657779e-03,   0.00000000e+00,  -1.78153513e-02,
#           2.92531783e-02,   3.77240904e-03,   1.26018744e-03,
#           6.36168527e-04,   3.72027498e-05,   6.24019201e-04,
#          -7.16711692e-04,  -2.34255596e-04,  -2.06791813e-04]])
