# %%
import  sys
sys.path.insert(0, "C:/projets_python/diabolo")


import warnings

import sklearn
import etude_variable.jouer as jouer
import etude_variable.lecture_data as ld
import pandas as pd
import numpy as np
import matplotlib
import scipy
import platform

# make sure to use position 1


print('Operating system version....', platform.platform())
print("Python version is........... %s.%s.%s" % sys.version_info[:3])
print('scikit-learn version is.....', sklearn.__version__)
print('pandas version is...........', pd.__version__)
print('numpy version is............', np.__version__)
print('matplotlib version is.......', matplotlib.__version__)
print('scipy version is.......', scipy.__version__)
# Out:
# Operating system version.... Windows-10-10.0.17134-SP0
# Python version is........... 3.6.5
# scikit-learn version is..... 0.19.1
# pandas version is........... 0.22.0
# numpy version is............ 1.14.2
# matplotlib version is....... 2.2.0
# scipy version is....... 1.0.0

# %%
def jouerlescourse(nb_itera, allure, mode_debug=0, actualise=0):
    
    global best_model_1,   best_model_2, best_model_3, best_model_4, best_model_5,\
            feature_columns1, feature_columns2, feature_columns3,\
    feature_columns4,      feature_columns5,response_column
    
    #ENTRAINE_ALLURE
    best_model, feature_columns, response_column = jouer.entraine_allure(allure=allure, 
                                                                                                                             nb_iter=nb_itera,
                                                                                                                        mode_debug=mode_debug,
                                                                                                                           actualise=actualise)
    
    
    
    
    if allure==1:
        best_model_1 = best_model
        feature_columns1 = feature_columns
        
    if allure==2:
        best_model_2 = best_model
        feature_columns2 = feature_columns
        
    if allure==3:
        best_model_3 = best_model
        feature_columns3 = feature_columns
        
    if allure==4:
        best_model_4 = best_model
        feature_columns4 = feature_columns
        
    if allure==5:
        best_model_5 = best_model
        feature_columns5 = feature_columns
        
            
    jouer.construireFichierCSV(allure=allure , best_model=best_model, 
                                      feature_columns=feature_columns,  
                                        response_column=response_column,
                                       mode_debug=mode_debug)

# %%
def jouerlescourse(nb_itera, allure, mode_debug=0, actualise=0):
    
    global best_model_1,   best_model_2, best_model_3, best_model_4, best_model_5,\
            feature_columns1, feature_columns2, feature_columns3,\
    feature_columns4,      feature_columns5,response_column
    
    #ENTRAINE_ALLURE
    best_model, feature_columns, response_column = jouer.entraine_allure(allure=allure, 
                                                                          nb_iter=nb_itera,mode_debug=mode_debug,actualise=actualise)
    
    if allure==1:
        best_model_1 = best_model
        feature_columns1 = feature_columns
        
    if allure==2:
        best_model_2 = best_model
        feature_columns2 = feature_columns
        
    if allure==3:
        best_model_3 = best_model
        feature_columns3 = feature_columns
        
    if allure==4:
        best_model_4 = best_model
        feature_columns4 = feature_columns
        
    if allure==5:
        best_model_5 = best_model
        feature_columns5 = feature_columns
        
            
    jouer.construireFichierCSV(allure=allure , best_model=best_model, 
                                      feature_columns=feature_columns,  
                                        response_column=response_column,
                                       mode_debug=mode_debug)

# %%
nb=2

mode_debug=0 # MODE DEBUG
actua=0# recalcul du model 0 = actua   1=pas actuia


jouerlescourse(nb_itera=nb, allure=1, mode_debug=mode_debug,actualise=actua)
jouerlescourse(nb_itera=nb, allure=2,mode_debug=mode_debug,actualise=actua)
jouerlescourse(nb_itera=nb, allure=3, mode_debug=mode_debug,actualise=actua)
jouerlescourse(nb_itera=nb, allure=4, mode_debug=mode_debug,actualise=actua)
jouerlescourse(nb_itera=nb, allure=5, mode_debug=mode_debug,actualise=actua)
# Out:
# Lecture data d:\data_diabolo.csv
# Fin de lecture  de d:\data_diabolo.csv
# Normalisation scaler ....
# Split ...
# class_weight =  [0.64084787 2.27496467]
#
# TEST DU FIT ......DIRECT
# ************************************************************  Accuracy: 79.52%
# Classification report
#
#              precision    recall  f1-score   support
#
#           0       0.81      0.97      0.88     32512
#           1       0.61      0.15      0.24      8970
#
# avg / total       0.76      0.80      0.74     41482
# c:\python\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
#                        importance
# feature
# PAR_RUESSITE_PLACE          0.109
# Point                       0.107
# PAR_ENT_REU_PLACE           0.105
# PAR_JOC_NB_COURSE           0.105
# PAR_REUSSITE_3P             0.104
# PAR_PLACE                   0.103
# PAR_REUSSITE_GAGNE          0.096
# PAR_JOC_REU_PLACE           0.093
# pAR_JOC_ECART_GAGNANT       0.091
# PAR_ENT_VICTOIRE            0.087
#
# EVAL SET ....
# c:\python\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# c:\python\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# c:\python\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# Accuracy is:  0.7951641675907622
# Evaluation TEST-----------------------------------------------------------------------
# ***********************************************************
#
# Scores des classes de test  [0.12800163 0.08664976 0.64393115 ... 0.3324629  0.19508116 0.2961739 ]  **************
# ***********************************************************
# TEST roc_auc_score :  0.5618845956337398
# c:\python\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# [[179030   4370]
#  [ 43071   8592]]
# c:\python\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# [[31632   880]
#  [ 7617  1353]]
# Classification Correcte des données de test : 32985/41482    79.516%
# c:\python\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# Score  TEST  :   79.516  ************************
#
# EVAL SET ....
# c:\python\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# c:\python\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# c:\python\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# Accuracy is:  0.7951641675907622
# TRAINING roc_auc_score :  0.5712404388595826
# c:\python\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# [[179030   4370]
#  [ 43071   8592]]
# c:\python\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# [[31632   880]
#  [ 7617  1353]]
#  CLASSIFICATION CORRECTE DES DONNEES DE Train  : 187622/235063    79.818%
# c:\python\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# c:\python\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:/projets_python/diabolo\etude_variable\jouer.py:271: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   test_x['v0'][i] = n
# C:/projets_python/diabolo\etude_variable\jouer.py:274: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   test_x['v1'][i] = n
# Score  TRAINING  :   79.818  ************************
# Sauvegarde modele ...
# Lecture data d:\data_jour.csv
# Fin de lecture  de d:\data_jour.csv
# Temps de calcul de la construction du fichier  est : 00:00:14
#
#
#  ALLER DANS APPLICATION DIABOLO ...Allure 1
# Lecture data d:\data_diabolo.csv
# Fin de lecture  de d:\data_diabolo.csv
# Normalisation scaler ....
# Split ...
# class_weight =  [0.68290515 1.86682868]
#
# TEST DU FIT ......DIRECT
# ************************************************************  Accuracy: 76.91%
# Classification report
#
#              precision    recall  f1-score   support
#
#           0       0.79      0.94      0.85     19523
#           1       0.65      0.33      0.43      7318
#
# avg / total       0.75      0.77      0.74     26841
# c:\python\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
#                        importance
# feature
# CO_PRIX                     0.143
# Point                       0.111
# PAR_JOC_NB_COURSE           0.107
# PAR_REUSSITE_GAGNE          0.080
# PAR_REUSSITE_3P             0.077
# PAR_ENT_REU_PLACE           0.072
# PAR_JOC_REU_PLACE           0.069
# PAR_RUESSITE_PLACE          0.069
# CORDE                       0.065
# PAR_ENT_VICTOIRE            0.064
# pAR_JOC_ECART_GAGNANT       0.053
# POIDS                       0.051
# PAR_PLACE                   0.040
#
# EVAL SET ....
# c:\python\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# c:\python\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# c:\python\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# Accuracy is:  0.769084609366268
# Evaluation TEST-----------------------------------------------------------------------
# ***********************************************************
#
# Scores des classes de test  [0.13288979 0.21362196 0.18886459 ... 0.40630466 0.1047253  0.54369956]  **************
# ***********************************************************
# TEST roc_auc_score :  0.6303003911672733
# c:\python\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# [[105999   5362]
#  [ 25019  15718]]
# c:\python\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# [[18264  1259]
#  [ 4939  2379]]
# Classification Correcte des données de test : 20643/26841    76.908%
# c:\python\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# Score  TEST  :   76.908  ************************
#
# EVAL SET ....
# c:\python\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# c:\python\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# c:\python\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# Accuracy is:  0.769084609366268
# TRAINING roc_auc_score :  0.6688455852272002
# c:\python\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# [[105999   5362]
#  [ 25019  15718]]
# c:\python\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# [[18264  1259]
#  [ 4939  2379]]
# c:\python\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# c:\python\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:/projets_python/diabolo\etude_variable\jouer.py:271: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   test_x['v0'][i] = n
# C:/projets_python/diabolo\etude_variable\jouer.py:274: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   test_x['v1'][i] = n
#  CLASSIFICATION CORRECTE DES DONNEES DE Train  : 121717/152098    80.025%
# Score  TRAINING  :   80.025  ************************
# Sauvegarde modele ...
# Lecture data d:\data_jour.csv
# Fin de lecture  de d:\data_jour.csv
# Temps de calcul de la construction du fichier  est : 00:00:13
#
#
#  ALLER DANS APPLICATION DIABOLO ...Allure 2
# Lecture data d:\data_diabolo.csv
# Fin de lecture  de d:\data_diabolo.csv
#
# Normalisation scaler ....
# Split ...
# class_weight =  [0.64423591 2.2332716 ]
#
# TEST DU FIT ......DIRECT
# ************************************************************  Accuracy: 78.62%
# Classification report
#
#              precision    recall  f1-score   support
#
#           0       0.80      0.97      0.88      4974
#           1       0.57      0.14      0.22      1411
#
# avg / total       0.75      0.79      0.73      6385
# c:\python\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
#                        importance
# feature
# Point                       0.127
# PAR_JOC_NB_COURSE           0.121
# PAR_REUSSITE_3P             0.119
# CO_PRIX                     0.094
# PAR_RUESSITE_PLACE          0.094
# PAR_REUSSITE_GAGNE          0.090
# PAR_ENT_REU_PLACE           0.084
# PAR_ENT_VICTOIRE            0.072
# PAR_JOC_REU_PLACE           0.071
# pAR_JOC_ECART_GAGNANT       0.066
# PAR_PLACE                   0.062
#
# EVAL SET ....
# c:\python\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# c:\python\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# c:\python\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# Accuracy is:  0.7862176977290525
# Evaluation TEST-----------------------------------------------------------------------
# ***********************************************************
#
# Scores des classes de test  [0.10859234 0.12888968 0.11762413 ... 0.33382675 0.17237477 0.07367185]  **************
# ***********************************************************
# TEST roc_auc_score :  0.5533605364479275
# c:\python\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# c:\python\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# c:\python\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# c:\python\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# [[27666   413]
#  [ 6440  1660]]
# [[4828  146]
#  [1219  192]]
# Classification Correcte des données de test : 5020/6385    78.622%
#
# Score  TEST  :   78.622  ************************
#
# EVAL SET ....
# c:\python\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# c:\python\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# Accuracy is:  0.7862176977290525
# TRAINING roc_auc_score :  0.5951148852949725
# c:\python\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# c:\python\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# [[27666   413]
#  [ 6440  1660]]
# [[4828  146]
#  [1219  192]]
#
#  CLASSIFICATION CORRECTE DES DONNEES DE Train  : 29326/36179    81.058%
# c:\python\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# c:\python\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:/projets_python/diabolo\etude_variable\jouer.py:271: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   test_x['v0'][i] = n
# C:/projets_python/diabolo\etude_variable\jouer.py:274: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   test_x['v1'][i] = n
# Score  TRAINING  :   81.058  ************************
# Sauvegarde modele ...
# Lecture data d:\data_jour.csv
# Fin de lecture  de d:\data_jour.csv
# Temps de calcul de la construction du fichier  est : 00:00:01
#
#
#  ALLER DANS APPLICATION DIABOLO ...Allure 3
# Lecture data d:\data_diabolo.csv
# Fin de lecture  de d:\data_diabolo.csv
#
# Normalisation scaler ....
# Split ...
# class_weight =  [0.67499464 1.9286152 ]
#
# TEST DU FIT ......DIRECT
# ************************************************************  Accuracy: 75.61%
# Classification report
#
#              precision    recall  f1-score   support
#
#           0       0.79      0.92      0.85       826
#           1       0.55      0.29      0.38       285
#
# avg / total       0.73      0.76      0.73      1111
# c:\python\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
#                        importance
# feature
# Point                       0.135
# PAR_JOC_NB_COURSE           0.113
# PAR_REUSSITE_GAGNE          0.096
# PAR_ENT_REU_PLACE           0.091
# PAR_REUSSITE_3P             0.089
# PAR_RUESSITE_PLACE          0.086
# PAR_ENT_VICTOIRE            0.083
# CO_PRIX                     0.081
# pAR_JOC_ECART_GAGNANT       0.070
# PAR_JOC_REU_PLACE           0.055
# POIDS                       0.052
# PAR_PLACE                   0.051
#
# EVAL SET ....
# Accuracy is:  0.7560756075607561
# Evaluation TEST-----------------------------------------------------------------------
# ***********************************************************
#
# Scores des classes de test  [0.47983864 0.48808503 0.35179812 ... 0.10153802 0.3267155  0.7636158 ]  **************
# ***********************************************************
# TEST roc_auc_score :  0.6026974215199015
# [[4449  214]
#  [ 937  695]]
# [[758  68]
#  [203  82]]
# Classification Correcte des données de test : 840/1111    75.608%
#
# Score  TEST  :   75.608  ************************
#
# EVAL SET ....
# Accuracy is:  0.7560756075607561
# TRAINING roc_auc_score :  0.6899823206679196
# [[4449  214]
#  [ 937  695]]
# [[758  68]
#  [203  82]]
#
#  CLASSIFICATION CORRECTE DES DONNEES DE Train  : 5144/6295    81.716%
# c:\python\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# c:\python\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# c:\python\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# c:\python\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# c:\python\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# c:\python\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# c:\python\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# c:\python\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# c:\python\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# c:\python\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# c:\python\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# c:\python\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# Score  TRAINING  :   81.716  ************************
# Sauvegarde modele ...
# Lecture data d:\data_jour.csv
# Fin de lecture  de d:\data_jour.csv
# c:\python\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:/projets_python/diabolo\etude_variable\jouer.py:271: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   test_x['v0'][i] = n
# C:/projets_python/diabolo\etude_variable\jouer.py:274: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   test_x['v1'][i] = n
# Temps de calcul de la construction du fichier  est : 00:00:00
#
#
#  ALLER DANS APPLICATION DIABOLO ...Allure 4
# Lecture data d:\data_diabolo.csv
# Fin de lecture  de d:\data_diabolo.csv
#
# Normalisation scaler ....
# Split ...
# class_weight =  [0.70638456 1.71133094]
#
# TEST DU FIT ......DIRECT
# ************************************************************  Accuracy: 74.11%
# Classification report
#
#              precision    recall  f1-score   support
#
#           0       0.76      0.92      0.83       465
#           1       0.65      0.34      0.45       207
#
# avg / total       0.73      0.74      0.71       672
# c:\python\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
#                        importance
# feature
# Point                       0.162
# CO_PRIX                     0.097
# PAR_JOC_NB_COURSE           0.096
# PAR_REUSSITE_3P             0.095
# PAR_RUESSITE_PLACE          0.094
# PAR_REUSSITE_GAGNE          0.085
# PAR_ENT_VICTOIRE            0.077
# PAR_ENT_REU_PLACE           0.074
# PAR_JOC_REU_PLACE           0.070
# PAR_PLACE                   0.056
# pAR_JOC_ECART_GAGNANT       0.053
# POIDS                       0.042
#
# EVAL SET ....
# Accuracy is:  0.7410714285714286
# Evaluation TEST-----------------------------------------------------------------------
# ***********************************************************
#
# Scores des classes de test  [0.65853965 0.66844434 0.07344399 0.26788086 0.4704807  0.4465833
#  0.38695168 0.43414357 0.09455479 0.4522179  0.29381293 0.57320863
#  0.12877372 0.22058237 0.0802408  0.6283866  0.4718068  0.11239856
#  0.25065875 0.45742175 0.33092546 0.12947515 0.36573178 0.12893797
#  0.38368607 0.08601765 0.24998346 0.33850372 0.28252724 0.40538856
#  0.22340965 0.07526236 0.07141909 0.27789894 0.5022893  0.39168134
#  0.49461985 0.4071773  0.45391387 0.5317836  0.56728166 0.2537148
#  0.07241578 0.30576125 0.08956251 0.07545999 0.28179288 0.38046342
#  0.2991122  0.32854688 0.47799882 0.4011969  0.24939746 0.46684992
#  0.19597146 0.41360396 0.07434577 0.22123696 0.6020078  0.65272856
#  0.49598593 0.23179425 0.14967982 0.2566527  0.3230902  0.15843935
#  0.09032353 0.44722423 0.3028627  0.13421886 0.55957353 0.5226827
#  0.3033244  0.66098386 0.23844005 0.6212774  0.5806144  0.15006757
#  0.31625408 0.22723423 0.14892791 0.29479656 0.6717768  0.47461873
#  0.35763532 0.28695986 0.32565808 0.15456077 0.39648008 0.34767255
#  0.25084433 0.16382337 0.1138299  0.09112557 0.22819588 0.67626595
#  0.41816363 0.21766755 0.12454101 0.34256068 0.5467407  0.4457099
#  0.17611885 0.22064953 0.23565291 0.4315044  0.4096878  0.4560121
#  0.24473396 0.1329054  0.28527057 0.13639234 0.15281363 0.24511363
#  0.38497964 0.5263655  0.47276086 0.38648054 0.2299425  0.20696646
#  0.55420244 0.32118776 0.44575575 0.1607878  0.1586498  0.3129387
#  0.5309091  0.12011005 0.511616   0.0731395  0.28505027 0.25540885
#  0.51149255 0.08031273 0.53607565 0.6063957  0.24817982 0.29922506
#  0.5799122  0.30677643 0.12143093 0.35726026 0.14831032 0.19221699
#  0.33260962 0.6876642  0.12747923 0.3185414  0.44684762 0.32508734
#  0.48501202 0.38602012 0.10596147 0.07366099 0.4087542  0.16921191
#  0.10984518 0.64164335 0.1815609  0.14233068 0.75841343 0.48026994]  **************
# ***********************************************************
# TEST roc_auc_score :  0.6306373694872993
# [[2546  148]
#  [ 611  501]]
# [[427  38]
#  [136  71]]
# Classification Correcte des données de test : 498/672    74.107%
#
# Score  TEST  :   74.107  ************************
#
# EVAL SET ....
# Accuracy is:  0.7410714285714286
# TRAINING roc_auc_score :  0.6978013357688014
# [[2546  148]
#  [ 611  501]]
# [[427  38]
#  [136  71]]
#
#  CLASSIFICATION CORRECTE DES DONNEES DE Train  : 3047/3806    80.058%
# Score  TRAINING  :   80.058  ************************
# Sauvegarde modele ...
# Lecture data d:\data_jour.csv
# Fin de lecture  de d:\data_jour.csv
# c:\python\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# c:\python\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# c:\python\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# c:\python\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# c:\python\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# c:\python\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# c:\python\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# c:\python\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# c:\python\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# c:\python\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# c:\python\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# c:\python\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-e857cd98d957> in <module>()
#       9 jouerlescourse(nb_itera=nb, allure=3, mode_debug=mode_debug,actualise=actua)
#      10 jouerlescourse(nb_itera=nb, allure=4, mode_debug=mode_debug,actualise=actua)
# ---> 11 jouerlescourse(nb_itera=nb, allure=5, mode_debug=mode_debug,actualise=actua)
#
# <ipython-input-3-6168bf59b301> in jouerlescourse(nb_itera, allure, mode_debug, actualise)
#      31                                       feature_columns=feature_columns,
#      32                                         response_column=response_column,
# ---> 33                                        mode_debug=mode_debug)
#
# C:/projets_python/diabolo\etude_variable\jouer.py in construireFichierCSV(allure, best_model, feature_columns, response_column, mode_debug)
#     155
#     156     df_numero_a_predire = df_numero_a_predire.groupby("ALLURE")
# --> 157     df_numero_a_predire = df_numero_a_predire.get_group(allure)
#     158     df_numero_a_predire = lecture_data.my_drop(df_numero_a_predire, 'ALLURE')
#     159     df_numero_a_predire = lecture_data.my_drop(df_numero_a_predire, 'PAR_ARRIVE')
#
# c:\python\lib\site-packages\pandas\core\groupby.py in get_group(self, name, obj)
#     763         inds = self._get_index(name)
#     764         if not len(inds):
# --> 765             raise KeyError(name)
#     766
#     767         return obj._take(inds, axis=self.axis, convert=False)
#
# KeyError: 5
