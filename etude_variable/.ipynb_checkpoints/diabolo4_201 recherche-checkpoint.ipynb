# %%
import  sys

#LOCALISATION DES DONNEES
sys.path.insert(0, "C:/projets_python/diabolo")

import warnings
warnings.filterwarnings("ignore")



#LIBRAIRIES PERSO
import etude_variable.MyLog as log
import etude_variable.jouer as jouer
import etude_variable.lecture_data as ld
import etude_variable.analyse as ana

# LIBRAIRIE PYHTON CLASSIQUES
import pandas as pd
import numpy as np
import matplotlib
import scipy
import platform

from collections import Counter

#ESTIMATEUR
import sklearn
import xgboost as xgb
from xgboost import XGBClassifier
from sklearn.ensemble import  RandomForestClassifier
from sklearn import neighbors, datasets
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import Imputer

#TRAINING
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
import dask_searchcv as dcv

#Evaluateur
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold
from sklearn.feature_selection import SelectFromModel

from evolutionary_search import EvolutionaryAlgorithmSearchCV
from sklearn.utils import class_weight

#outils
from dask.diagnostics import ProgressBar


#Metriques
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.model_selection import learning_curve
from sklearn import  metrics
from sklearn.metrics import  roc_auc_score
from sklearn.metrics import  classification_report
import time


#Graphique
from matplotlib import pyplot
from matplotlib import pyplot as plt
import seaborn as sns

print('Operating system version....', platform.platform())
print("Python version is........... %s.%s.%s" % sys.version_info[:3])
print('scikit-learn version is.....', sklearn.__version__)
print('pandas version is...........', pd.__version__)
print('numpy version is............', np.__version__)
print('matplotlib version is.......', matplotlib.__version__)
print('scipy version is.......', scipy.__version__)
# Out:
# Operating system version.... Windows-10-10.0.16299-SP0
# Python version is........... 3.6.5
# scikit-learn version is..... 0.19.1
# pandas version is........... 0.22.0
# numpy version is............ 1.14.2
# matplotlib version is....... 2.2.0
# scipy version is....... 1.0.0

# %%
def split_dataset(dataset, train_percentage, feature_headers,
                                  target_header,random_state=42,mode_debug=0):

    train_x, test_x, train_y, test_y = train_test_split(dataset[feature_headers], dataset[target_header],
                                                        train_size=train_percentage, test_size=None, random_state=42)


    if mode_debug==1:
        # Train and Test dataset size details
        print("--------------------------------")
        print("Train_x Shape :: ", train_x.shape)
        print("Train_y Shape :: ", train_y.shape)
        print("Test_x Shape :: ", test_x.shape)
        print("Test_y Shape :: ", test_y.shape)
        print("--------------------------------")

    return train_x, test_x, train_y, test_y


def construireFichierCSV(allure, best_model, feature_columns, response_column, mode_debug=0):
    # lecture des données a jouer


    xnames = ['ALLURE', 'CO_DISTANCE',
              'CO_PRIX', 'HIPPO',
              'IDCOURSE', 'IDPARTCIPANT',
              'PAR_AGE', 'PAR_ARRIVE',
              'PAR_CARRIERE',
              'PAR_CARRIERE_Q',
              'PAR_CLASSE_AGE',
              'PAR_COTEDER',
              'PAR_ENT_ECART_GAGNANT',
              'PAR_ENT_RAPPORT_GAGNANT_M',
              'PAR_ENT_REU_PLACE',
              'PAR_ENT_REUSSITE_GAGNE',
              'PAR_ENT_VICTOIRE',
              'PAR_GAIN',
              'pAR_JOC_ECART_GAGNANT',
              'PAR_JOC_ECART_PLACE',
              'PAR_JOC_NB_COURSE',
              'PAR_JOC_PLACE_3P',
              'pAR_JOC_RAPPORT_GAGNANT_M',
              'PAR_JOC_REU_PLACE',
              'pAR_JOC_REUSSITE_GAGNE',
              'pAR_JOC_VICTOIRE',
              'PAR_NP',
              'PAR_NUM',
              'PAR_PLACE',
              'PAR_PLACE_Q',
              'PAR_REUSSITE_3P',
              'PAR_REUSSITE_GAGNE',
              'PAR_REUSSITE_QUINTE',
              'PAR_RUESSITE_PLACE',
              'autostart',
              'cendre',
              'grande_piste',
              'Point',
              'Nb_partant', 'PAR_PROPRIO',
              'NOM_JOC',
              'NOM_ENTR',
              'POIDS',
              'CORDE',
              'CHEVAL','MUSIC_CHEVAL', 'MUSIC_ENT',
              'MUSIC_JOC',
              'PAR_VALEUR',
              'FIN_ligne']



    df_numero_a_predire = ld.lecture_data('d:\data_jour.csv', xnames, ['IDPARTCIPANT', 'IDCOURSE'],allure=allure,avec_index=True)
    df_numero_a_predire = df_numero_a_predire.groupby("ALLURE")
    df_numero_a_predire = df_numero_a_predire.get_group(allure)
    df_numero_a_predire = ld.my_drop(df_numero_a_predire, 'ALLURE')
    df_numero_a_predire = ld.my_drop(df_numero_a_predire, 'PAR_ARRIVE')
    df_numero_a_predire['SELECTION'] = 0


    train_x, test_x, train_y, test_y = split_dataset(df_numero_a_predire, 0, feature_columns, response_column)
    test_y = test_y['SELECTION'].ravel()

    # sauvegarde
    y_pred = best_model.predict(test_x)
    df_pred = pd.DataFrame.from_dict(y_pred)
    test_copy = test_x.copy()
    
    # UTILISATION DE BEST_MODEL
    PROBA = best_model.predict_proba(test_x)
    #print("PROBA \n %s" ,PROBA)

    df_proba = pd.DataFrame.from_dict(PROBA)
    #print(   df_proba)

    #print("df final=")
    df_final = pd.concat([df_proba, df_pred], axis=1)
    print(df_final.head(5))

    test_x = test_copy.copy()
    test_x = ld.my_drop(test_x, 'PAR_CLASSE_AGE')
    test_x = ld.my_drop(test_x, 'PAR_ENT_ECART_GAGNANT')
    test_x = ld.my_drop(test_x, 'PAR_ENT_RAPPORT_GAGNANT_M')
    test_x = ld.my_drop(test_x, 'PAR_ENT_REU_PLACE')
    test_x = ld.my_drop(test_x, 'PAR_ENT_REUSSITE_GAGNE')
    test_x = ld.my_drop(test_x, 'PAR_ENT_VICTOIRE')
    test_x = ld.my_drop(test_x, 'PAR_GAIN')
    test_x = ld.my_drop(test_x, 'pAR_JOC_ECART_GAGNANT')
    test_x = ld.my_drop(test_x, 'PAR_JOC_ECART_PLACE')
    test_x = ld.my_drop(test_x, 'PAR_JOC_NB_COURSE')
    test_x = ld.my_drop(test_x, 'PAR_JOC_PLACE_3P')
    test_x = ld.my_drop(test_x, 'PAR_REUSSITE_GAGNE')
    test_x = ld.my_drop(test_x, 'PAR_REUSSITE_QUINTE')
    test_x = ld.my_drop(test_x, 'PAR_RUESSITE_PLACE')
    test_x = ld.my_drop(test_x, 'CO_PRIX')
    test_x = ld.my_drop(test_x, 'PAR_CARRIERE')
    test_x = ld.my_drop(test_x, 'PAR_CARRIERE_Q')
    test_x = ld.my_drop(test_x, 'pAR_JOC_RAPPORT_GAGNANT_M')
    test_x = ld.my_drop(test_x, 'pAR_JOC_REUSSITE_GAGNE')
    test_x = ld.my_drop(test_x, 'pAR_JOC_VICTOIRE')
    test_x = ld.my_drop(test_x, 'PAR_PLACE')
    test_x = ld.my_drop(test_x, 'PAR_PLACE_Q')
    test_x = ld.my_drop(test_x, 'PAR_CLASSE_AGE')
    test_x = ld.my_drop(test_x, 'pAR_JOC_VICTOIRE')
    test_x = ld.my_drop(test_x, 'PAR_REUSSITE_3P')
    test_x = ld.my_drop(test_x, 'PAR_JOC_REU_PLACE')
    test_x = ld.my_drop(test_x, 'PAR_NUM')
    test_x = ld.my_drop(test_x, 'PAR_COTEDER')
    test_x = ld.my_drop(test_x, 'CORDE')
    test_x = ld.my_drop(test_x, 'musique')
    test_x = ld.my_drop(test_x, 'CHEVAL')
    test_x = ld.my_drop(test_x, 'Nb_partant')

    test_x = ld.my_drop(test_x, 'autostart')
    test_x = ld.my_drop(test_x, 'grande_piste')
    test_x = ld.my_drop(test_x, 'cendre')

    test_x = ld.my_drop(test_x, 'PAR_PROPRIO')
    test_x = ld.my_drop(test_x, 'NOM_JOC')
    test_x = ld.my_drop(test_x, 'NOM_ENTR')

    test_x = ld.my_drop(test_x, 'HIPPO')
    test_x = ld.my_drop(test_x, 'PAR_AGE')
    test_x = ld.my_drop(test_x, 'POIDS')
    test_x = ld.my_drop(test_x, 'CO_DISTANCE')
    test_x = ld.my_drop(test_x, 'CO_PRIX')
    test_x = ld.my_drop(test_x, 'PAR_GAIN_NORMA')
    test_x = ld.my_drop(test_x, 'CHEVAL2')
    test_x = ld.my_drop(test_x, 'PAR_REUSSITE_3P2')
    test_x = ld.my_drop(test_x, 'PAR_REUSSITE_QUINTE2')
    test_x = ld.my_drop(test_x, 'PAR_CLASSE_AGE2')
    test_x = ld.my_drop(test_x, 'PAR_COTEDER2')

    test_x = ld.my_drop(test_x, 'MUSIC_CHEVAL')
    test_x = ld.my_drop(test_x, 'MUSIC_ENT')
    test_x = ld.my_drop(test_x, 'MUSIC_JOC')
    test_x = ld.my_drop(test_x, 'PAR_VALEUR')

    test_x['v0'] = 0.0
    test_x['v1'] = 0.0
    test_x['sel'] = 0

    print("\n\nTest_x", test_x.head(4))

    # test_x
    cumul = 1
    nb_rows = len(df_proba.index)
    #rint("nb_rows=", nb_rows)

    for i in range(0, nb_rows):
        n = df_proba[0][i]
        test_x['v0'][i] = n

        n = df_proba[1][i]
        test_x['v1'][i] = n


    if (allure == 1):
        test_x.to_csv("d:\py_resultat_trot.csv")

    if (allure == 2):
        test_x.to_csv("d:\py_resultat_galop.csv")

    if (allure == 3):
        test_x.to_csv("d:\py_resultat_trot_monte.csv")

    if (allure == 4):
        test_x.to_csv("d:\py_resultat_haie.csv")

    if (allure == 5):
        test_x.to_csv("d:\py_resultat_steeple.csv")


    print("\n\n ALLER DANS APPLICATION DIABOLO ...Allure %s" % allure)

# %%
def explo_variable(dataset, svariable):

     # On calcule le quantile 0,25 qui est le quartile Q1
    mediane = np.median(dataset)
    print ("La mediane              "+svariable+"    : ", round(mediane, 2))

    maxx = np.max(dataset)
    print ("Le max              "+svariable+"    : ", round(maxx, 2))
    
    minn = np.min(dataset)
    print ("Le min              "+svariable+"    : ", round(minn, 2))
    
    
    moy = np.mean(dataset)
    print ("La moyenne               "+svariable+"   : ", round(moy, 2))

    variance = np.var(dataset)
    print ("La variance est          "+svariable+"   : ", round(variance, 2))
    
    ecartType = np.std(dataset)
    print ("Le ecart type            "+svariable+"   : ", round(ecartType, 2))
     
    print("")      
    
   # print(dataset.describe())
    
    print("")    
    

    
def CorrectionDesequilibre(train_x,train_y,feature_columns):

    from imblearn.combine import SMOTEENN
    from imblearn.over_sampling import SMOTE
    #from imblearn.under_sampling import TomekLinks
    #f"rom imblearn.under_sampling import RandomUnderSampler
    #from imblearn.under_sampling import AllKNN


    print('\nOriginal dataset shape {}'.format(Counter(train_y)))
    #sm = SMOTEENN(ratio='minority',n_jobs=4, random_state=42,smote=SMOTE(),n_neighbors=5)
    sm = SMOTE(ratio='auto', n_jobs=3, random_state=42,k_neighbors=50)
    X_res, y_res = sm.fit_sample(train_x, train_y)
    print('\nResampled dataset shape {}'.format(Counter(y_res)))
    # reconstitution DATAFRAME
    train_x = pd.DataFrame(X_res, columns=feature_columns)
    train_y = pd.Series(y_res)
    return train_x,train_y

# %%
def my_fit(estimateur, test_x,test_y, train_x, train_y, verbose=False):
    nb_split=80

    

    # Correction du desequiilibre
    #train_x, train_y = smot2(train_x=train_x, train_y=train_y, feature_columns=featurecolums)
    #test_x, test_y = smot2(train_x=test_x, train_y=test_y, feature_columns=featurecolums)


    log.traceLogInfo("\nTEST DU FIT ......DIRECT")
    #kfold = StratifiedKFold(n_splits=nb_split, shuffle=False, random_state=None)
    
    model=estimateur
    
    eval_set = [(train_x, train_y), (test_x, test_y)]
    model.fit(train_x, train_y, eval_metric=["error", "auc"], eval_set=eval_set, verbose=verbose, early_stopping_rounds=10)
    y_pred = model.predict(test_x)
    predictions = [round(value) for value in y_pred]

    
    return model,y_pred,predictions


def my_fit2(estimateur, train_x, train_y)
    kfold = StratifiedKFold(n_splits=20 random_state=7)
    results = cross_val_score(estimateur, train_x, train_y cv=kfold)
    print("Accuracy: %.2f%% (%.2f%%)" % (results.mean()*100, results.std()*100))
    
    y_pred = model.predict(test_x)
    predictions = [round(value) for value in y_pred]
    return model,y_pred,predictions

# %%
def afficheEvalSet(mybest_model,
                    set_train,
                   set_train_cible,
                   set_test,
                   set_test_cible,
                   mode_debug=0,
                   type_eval=1):

    print("\nEVAL SET ....")

    set_test_cible_predicted = mybest_model.predict(set_test)
    set_train_cible_predicted = mybest_model.predict(set_train)

    print('Accuracy is: ', mybest_model.score(set_test, set_test_cible))  # accuracy
    if type_eval==1:
                print("Evaluation TEST-----------------------------------------------------------------------")
                set_test_cible_probabilities = mybest_model.predict_proba(set_test)
                score = set_test_cible_probabilities[:, 1]
                print("***********************************************************  ")
                print("\nScores des classes de test  %s" %score, " **************  ")
                print("***********************************************************  ")
                auc = roc_auc_score(set_test_cible, set_test_cible_predicted)
                print("TEST roc_auc_score :  %s" % auc)
    else:
                set_train_cible_probabilities = mybest_model.predict_proba(set_train)
                auc = roc_auc_score(set_train_cible, set_train_cible_predicted)
                print("TRAINING roc_auc_score :  %s" % auc)
    
    for x, y in [(set_train, set_train_cible), (set_test, set_test_cible)]:
            yp = mybest_model.predict(x)
            cm = confusion_matrix(y, yp.ravel())
            print(cm)

    import matplotlib.pyplot as plt

    if mode_debug == 1:
        plt.matshow(cm)
        plt.title('Confusion matrix')
        plt.colorbar()
        plt.ylabel('True label')
        plt.xlabel('Predicted label')

    if type_eval==1:
        ntotal = len(set_test)
        correct = set_test_cible == set_test_cible_predicted
        numCorrect = sum(correct)
        percent = round((100.0 * numCorrect) / ntotal, 3)

        log.traceLogInfo("Classification Correcte des données de test : {0:d}/{1:d}  {2:8.3f}%".format(numCorrect, ntotal, percent))

        prediction_score = 100.0 * mybest_model.score(set_test, set_test_cible)
        log.traceLogInfo('\nScore  TEST  : %8.3f  ************************' % prediction_score)
    else:
        ntotal = len(set_train)
        correct = set_train_cible== set_train_cible_predicted
        numCorrect = sum(correct)
        percent = round((100.0 * numCorrect) / ntotal, 3)

        log.traceLogInfo("\n CLASSIFICATION CORRECTE DES DONNEES DE Train  : {0:d}/{1:d}  {2:8.3f}%".format(numCorrect, ntotal, percent))

        prediction_score = 100.0 * mybest_model.score(set_train, set_train_cible)
        log.traceLogInfo('Score  TRAINING  : %8.3f  ************************' % prediction_score)

# %%
#Evaluation 1

# %%
def plot_importance(feature_columns, model):
    importances = pd.DataFrame({'feature': feature_columns, 'importance': np.round(model.feature_importances_, 3)})
    importances = importances.sort_values('importance', ascending=False).set_index('feature')
    print("")
    print( importances)
    importances.plot.bar()

def plot_2(model,cr1="auc",cr2="error"):
    
        # retrieve performance metrics
        results = model.evals_result()
        epochs = len(results['validation_0'][cr1])
        x_axis = range(0, epochs)

        # plot log loss
        fig, ax = pyplot.subplots()
        ax.plot(x_axis, results['validation_0'][cr2], label='Train')
        ax.plot(x_axis, results['validation_1'][cr2], label='Test')
        ax.legend()
        pyplot.ylabel('auc')
        pyplot.title('XGBoost Error')
        pyplot.show()

        # plot classification error
        fig, ax = pyplot.subplots()
        ax.plot(x_axis, results['validation_0'][cr1], label='Train')
        ax.plot(x_axis, results['validation_1'][cr1], label='Test')
        ax.legend()
        pyplot.ylabel('Classification Auc')
        pyplot.title('XGBoost Classification Auc')
        pyplot.show()
    
    
    
def evaluation_1(test_y, predictions,featurecolums, model):
    print(classification_report(test_y, predictions))
    plot_importance(feature_columns=featurecolums,model=model)
    from sklearn.feature_selection import SelectKBest
    from sklearn.feature_selection import chi2
    names = feature_columns
    print("----------KBEST-----------------")
    
    for n in range(0, len(names)):
        test = SelectKBest(score_func=chi2, k=9)
        fit = test.fit(train_x, train_y)
        print(names[n],'   ', fit.scores_[n])
    

    print("--------------------------")
    
def evaluation_2(model, train_x, train_y, test_x, test_y):    
    from sklearn.feature_selection import RFE
    rfc=model
    # create the RFE model and select 4 attributes
    rfe_model = RFE(rfc, 9, step=1)
    rfe_model = rfe_model.fit(train_x, train_y)
    # summarize the selection of the attributes
    print(rfe_model.support_)
    print(rfe_model.ranking_)

    # evaluate the model on testing set
    pred_y = rfe_model.predict(test_x)
    predictions = [round(value) for value in pred_y]
    accuracy = accuracy_score(test_y, predictions)
    print("Test Accuracy: %.2f%%" % (accuracy*100.0))
    print(train_x.mean()   )

# %% [markdown]
# # CHAMPS et INDEX

# %%
xnames = ['ALLURE', 'CO_DISTANCE',
              'CO_PRIX', 'HIPPO',
              'IDCOURSE', 'IDPARTCIPANT',
              'PAR_AGE', 'PAR_ARRIVE',
              'PAR_CARRIERE',
              'PAR_CARRIERE_Q',
              'PAR_CLASSE_AGE',
              'PAR_COTEDER',
              'PAR_ENT_ECART_GAGNANT',
              'PAR_ENT_RAPPORT_GAGNANT_M',
              'PAR_ENT_REU_PLACE',
              'PAR_ENT_REUSSITE_GAGNE',
              'PAR_ENT_VICTOIRE',
              'PAR_GAIN',
              'pAR_JOC_ECART_GAGNANT',
              'PAR_JOC_ECART_PLACE',
              'PAR_JOC_NB_COURSE',
              'PAR_JOC_PLACE_3P',
              'pAR_JOC_RAPPORT_GAGNANT_M',
              'PAR_JOC_REU_PLACE',
              'pAR_JOC_REUSSITE_GAGNE',
              'pAR_JOC_VICTOIRE',
              'PAR_NP',
              'PAR_NUM',
              'PAR_PLACE',
              'PAR_PLACE_Q',
              'PAR_REUSSITE_3P',
              'PAR_REUSSITE_GAGNE',
              'PAR_REUSSITE_QUINTE',
              'PAR_RUESSITE_PLACE',
              'autostart',
              'cendre',
              'grande_piste',
              'Point',
              'Nb_partant', 'PAR_PROPRIO',
              'NOM_JOC',
              'NOM_ENTR',
              'POIDS',
              'CORDE', 'CHEVAL', 'MUSIC_CHEVAL',
              'MUSIC_ENT',
              'MUSIC_JOC',
              'PAR_VALEUR',
              'FIN_ligne']

index_col = ['IDPARTCIPANT', 'IDCOURSE']


def assign_selection(W):
    if W < 4:
        return 1
    else:
        return 0
    
    # Creating bins for the win column
def assign_selection2(W):
    if W == 1.0:
        return 1
    if W == 0.0:
        return 0

# %% [markdown]
# # LECTURE DES DONNEES

# %%
allure_etudier=1

# %%
  # Lecture des données sans index
df = ld.lecture_data('d:\data_diabolo.csv', xnames, xindex_col=index_col, allure=allure_etudier, avec_index=False)
print(df.info())
# Out:
# Lecture data d:\data_diabolo.csv
# Fin de lecture  de d:\data_diabolo.csv
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 573400 entries, 0 to 573399
# Data columns (total 32 columns):
# ALLURE                       573400 non-null int64
# IDCOURSE                     573400 non-null int64
# IDPARTCIPANT                 573400 non-null int64
# PAR_AGE                      573400 non-null int64
# PAR_ARRIVE                   573400 non-null int64
# PAR_CARRIERE                 573400 non-null int64
# PAR_CARRIERE_Q               573400 non-null int64
# PAR_ENT_ECART_GAGNANT        573400 non-null int64
# PAR_ENT_RAPPORT_GAGNANT_M    573400 non-null float64
# PAR_ENT_REU_PLACE            573400 non-null float64
# PAR_ENT_REUSSITE_GAGNE       573400 non-null float64
# PAR_ENT_VICTOIRE             573400 non-null int64
# pAR_JOC_ECART_GAGNANT        573400 non-null int64
# PAR_JOC_ECART_PLACE          573400 non-null int64
# PAR_JOC_NB_COURSE            573400 non-null int64
# PAR_JOC_PLACE_3P             573400 non-null int64
# pAR_JOC_RAPPORT_GAGNANT_M    573400 non-null float64
# PAR_JOC_REU_PLACE            573400 non-null float64
# pAR_JOC_REUSSITE_GAGNE       573400 non-null float64
# pAR_JOC_VICTOIRE             573400 non-null int64
# PAR_NUM                      573400 non-null int64
# PAR_PLACE                    573400 non-null int64
# PAR_PLACE_Q                  573400 non-null int64
# PAR_REUSSITE_3P              573400 non-null float64
# PAR_REUSSITE_GAGNE           573400 non-null float64
# PAR_REUSSITE_QUINTE          573400 non-null float64
# PAR_RUESSITE_PLACE           573400 non-null float64
# Point                        573400 non-null int64
# Nb_partant                   573400 non-null int64
# PAR_PROPRIO                  573400 non-null int64
# NOM_JOC                      573400 non-null int64
# NOM_ENTR                     573400 non-null int64
# dtypes: float64(10), int64(22)
# memory usage: 140.0 MB
# None

# %%
explo_variable(df['PAR_REUSSITE_3P'],"PAR_REUSSITE_3P")
# Out:
# La mediane              PAR_REUSSITE_3P    :  0.27
# Le max              PAR_REUSSITE_3P    :  1.0
# Le min              PAR_REUSSITE_3P    :  0.0
# La moyenne               PAR_REUSSITE_3P   :  0.29
# La variance est          PAR_REUSSITE_3P   :  0.03
# Le ecart type            PAR_REUSSITE_3P   :  0.18

# %% [markdown]
# # Filtre des données  :  Allure

# %%
#Filtre des données¶
df2=df[df.Point>0]
    #df = df[df.PAR_COTEDER > 0]
df2 = df2[df2.PAR_ARRIVE > 0]  # On garde la ligne qui possede information arrivée

df2 = df2.groupby("ALLURE")
df2 = df2.get_group(allure_etudier)
df2 = ld.my_drop(df2, 'ALLURE')

if allure_etudier == 2 or allure_etudier == 4 or allure_etudier == 5:
    df2 = df2[df2.POIDS > 0]
    df2 = df2[df2.POIDS < 80]
#  on a lu les données avant l 'ajout de la colonne SELECTIOB
df2['SELECTION2'] = df2['PAR_ARRIVE'].apply(assign_selection)

df2.drop(["PAR_ARRIVE"], axis=1, inplace=True)
print(df2.shape)
# Out:
# (293140, 31)

# %% [markdown]
# # Definition de la cible

# %%
Lib_features_df = df2.columns
xdata = df2.values
df_gagnant = pd.DataFrame(data=xdata, columns=Lib_features_df)

df_gagnant['SELECTION'] = df_gagnant['SELECTION2'].apply(assign_selection2)
df_gagnant.drop(["SELECTION2"], axis=1, inplace=True)
df_gagnant = df_gagnant.set_index(index_col)

df_gagnant_len = len(df_gagnant.columns) - 1
Lib_features = df_gagnant.columns[:df_gagnant_len]
feature_columns = Lib_features  ##<<<<<<<<<<<<<<<<
response_column = ['SELECTION']  ##<<<<<<<<<<<<<<<<
log.traceLogdebug("Features                   : %s " % Lib_features, " <<<<************")

print("(1) Shape df_gagnant  ", df_gagnant.shape,"\n")
print("(2) FEATURES ",Lib_features)
print("(3) response column ",response_column)
# df_gagnant, feature_columns, response_column, ratio SONT DEFINI
# Out:
# (1) Shape df_gagnant   (293140, 29)
#
# (2) FEATURES  Index(['PAR_AGE', 'PAR_CARRIERE', 'PAR_CARRIERE_Q', 'PAR_ENT_ECART_GAGNANT',
#        'PAR_ENT_RAPPORT_GAGNANT_M', 'PAR_ENT_REU_PLACE',
#        'PAR_ENT_REUSSITE_GAGNE', 'PAR_ENT_VICTOIRE', 'pAR_JOC_ECART_GAGNANT',
#        'PAR_JOC_ECART_PLACE', 'PAR_JOC_NB_COURSE', 'PAR_JOC_PLACE_3P',
#        'pAR_JOC_RAPPORT_GAGNANT_M', 'PAR_JOC_REU_PLACE',
#        'pAR_JOC_REUSSITE_GAGNE', 'pAR_JOC_VICTOIRE', 'PAR_NUM', 'PAR_PLACE',
#        'PAR_PLACE_Q', 'PAR_REUSSITE_3P', 'PAR_REUSSITE_GAGNE',
#        'PAR_REUSSITE_QUINTE', 'PAR_RUESSITE_PLACE', 'Point', 'Nb_partant',
#        'PAR_PROPRIO', 'NOM_JOC', 'NOM_ENTR'],
#       dtype='object')
# (3) response column  ['SELECTION']

# %% [markdown]
# # CORRELATION

# %%
#Enfin, quelque chose de vraiment cool que vous pouvez mettre 

#dans une carte de chaleur est une matrice de corrélation. 
#Pandas DataFrame a une méthode corr qui calcule le coefficient de corrélation de Pearson (peut être un autre)
#entre tous les couples de colonnes numériques du DataFrame.

fig, ax = plt.subplots(figsize=(15,15))
sns.heatmap(df_gagnant.corr(), annot=True, fmt=".2f", linewidths=.4, ax=ax)

# %%
target_count = df_gagnant['SELECTION'].value_counts()


print('Proportion:', round(target_count[0] / target_count[1], 2), ': 1')
target_count.plot(kind='bar', title='Count (target)')

normal_trans_perc = sum(df_gagnant['SELECTION'] == 0) / (sum(df_gagnant['SELECTION'] == 0) + sum(df_gagnant['SELECTION'] == 1))
fraud_trans_perc = 1 - normal_trans_perc
print('Total number of records : {} '.format(len(df_gagnant)))
print('Nombre de participations avec SELECTION = 0 : {}'.format(sum(df_gagnant['SELECTION'] == 0)))
print('Nombre de participations avec SELECTION = 1  : {}'.format(sum(df_gagnant['SELECTION'] == 1)))
print('Pourcentage 0: {:.4f}%,  pourcentage 1 : {:.4f}%'.format(normal_trans_perc * 100,fraud_trans_perc * 100))
# Out:
# Proportion: 3.57 : 1
# Total number of records : 293140
# Nombre de participations avec SELECTION = 0 : 229046
# Nombre de participations avec SELECTION = 1  : 64094
# Pourcentage 0: 78.1354%,  pourcentage 1 : 21.8646%

# %% [markdown]
# # Definition des set

# %%
from sklearn.model_selection import train_test_split

train_x, test_x, train_y, test_y = train_test_split(df_gagnant[feature_columns],
                                                     df_gagnant[response_column], test_size=0.33, random_state=42)
train_eval_X =  df_gagnant[feature_columns]
train_eval_Y=  df_gagnant[response_column]





print("Train_x",train_x.shape)
print("Train y",train_y.shape)
print("Test x",test_x.shape)
print("Test y",test_y.shape)

print("train_eval_X",train_eval_X.shape)
print("train_eval_Y",train_eval_Y.shape)

print("Test x",test_x.shape)
print("Test y",test_y.shape)

test_y = test_y['SELECTION'].ravel()
train_y = train_y['SELECTION'].ravel()
# Out:
# Train_x (196403, 28)
# Train y (196403, 1)
# Test x (96737, 28)
# Test y (96737, 1)
# train_eval_X (293140, 28)
# train_eval_Y (293140, 1)
# Test x (96737, 28)
# Test y (96737, 1)

# %% [markdown]
# # ESTIMATEUR

# %%
model=XGBClassifier(base_score=0.5,
                  booster='gbtree',
                colsample_bylevel=0.6,
                colsample_bytree=0.8,
                 gamma=0.01,
                 learning_rate=0.07, #ok
                max_delta_step=3, #ok
                max_depth=6, #ok
                max_features='sqrt',
                min_child_weight=8, #ok
                n_estimators=1900,#ok
                n_jobs=3,#ok
                nthread=None,
                objective='binary:logistic',
                 random_state=10,
                reg_alpha=0.1, #ok
                reg_lambda=2.5,
                scale_pos_weight=1,
                 seed=800,
                subsample=0.99,
                silent=True
                )

# %%
model,y_pred,predictions=my_fit(model, test_x,test_y, train_x, train_y, verbose=True)
print(model)
# Out:
# TEST DU FIT ......DIRECT
# [0]	validation_0-error:0.210007	validation_0-auc:0.719442	validation_1-error:0.210209	validation_1-auc:0.713163
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-error:0.20935	validation_0-auc:0.727783	validation_1-error:0.208338	validation_1-auc:0.721469
# [2]	validation_0-error:0.208266	validation_0-auc:0.731193	validation_1-error:0.207842	validation_1-auc:0.724577
# [3]	validation_0-error:0.208622	validation_0-auc:0.73188	validation_1-error:0.207925	validation_1-auc:0.725057
# [4]	validation_0-error:0.208042	validation_0-auc:0.732487	validation_1-error:0.207408	validation_1-auc:0.725817
# [5]	validation_0-error:0.207675	validation_0-auc:0.733853	validation_1-error:0.207542	validation_1-auc:0.727008
# [6]	validation_0-error:0.207792	validation_0-auc:0.735372	validation_1-error:0.207439	validation_1-auc:0.728119
# [7]	validation_0-error:0.207476	validation_0-auc:0.735431	validation_1-error:0.20717	validation_1-auc:0.728139
# [8]	validation_0-error:0.207252	validation_0-auc:0.735697	validation_1-error:0.207201	validation_1-auc:0.728251
# [9]	validation_0-error:0.207125	validation_0-auc:0.736297	validation_1-error:0.206953	validation_1-auc:0.728875
# [10]	validation_0-error:0.207095	validation_0-auc:0.737321	validation_1-error:0.207025	validation_1-auc:0.729802
# [11]	validation_0-error:0.206809	validation_0-auc:0.737988	validation_1-error:0.206767	validation_1-auc:0.730255
# [12]	validation_0-error:0.206535	validation_0-auc:0.738061	validation_1-error:0.20686	validation_1-auc:0.730329
# [13]	validation_0-error:0.206529	validation_0-auc:0.738682	validation_1-error:0.206901	validation_1-auc:0.730887
# [14]	validation_0-error:0.206331	validation_0-auc:0.739011	validation_1-error:0.206725	validation_1-auc:0.731122
# [15]	validation_0-error:0.206407	validation_0-auc:0.739441	validation_1-error:0.206912	validation_1-auc:0.731461
# [16]	validation_0-error:0.20627	validation_0-auc:0.740082	validation_1-error:0.206767	validation_1-auc:0.731902
# [17]	validation_0-error:0.206377	validation_0-auc:0.740354	validation_1-error:0.206736	validation_1-auc:0.732026
# [18]	validation_0-error:0.20626	validation_0-auc:0.740483	validation_1-error:0.206787	validation_1-auc:0.732024
# [19]	validation_0-error:0.206229	validation_0-auc:0.740994	validation_1-error:0.206756	validation_1-auc:0.732225
# [20]	validation_0-error:0.206188	validation_0-auc:0.741341	validation_1-error:0.206632	validation_1-auc:0.732421
# [21]	validation_0-error:0.206127	validation_0-auc:0.741801	validation_1-error:0.206756	validation_1-auc:0.732669
# [22]	validation_0-error:0.20601	validation_0-auc:0.742069	validation_1-error:0.206539	validation_1-auc:0.732834
# [23]	validation_0-error:0.205959	validation_0-auc:0.742415	validation_1-error:0.206612	validation_1-auc:0.733103
# [24]	validation_0-error:0.2057	validation_0-auc:0.742888	validation_1-error:0.206684	validation_1-auc:0.73339
# [25]	validation_0-error:0.205689	validation_0-auc:0.74326	validation_1-error:0.206436	validation_1-auc:0.733586
# [26]	validation_0-error:0.205628	validation_0-auc:0.7436	validation_1-error:0.206395	validation_1-auc:0.733812
# [27]	validation_0-error:0.205537	validation_0-auc:0.743946	validation_1-error:0.206457	validation_1-auc:0.73405
# [28]	validation_0-error:0.20543	validation_0-auc:0.744339	validation_1-error:0.206415	validation_1-auc:0.734232
# [29]	validation_0-error:0.20543	validation_0-auc:0.744692	validation_1-error:0.206384	validation_1-auc:0.734472
# [30]	validation_0-error:0.205399	validation_0-auc:0.744972	validation_1-error:0.206457	validation_1-auc:0.734673
# [31]	validation_0-error:0.205353	validation_0-auc:0.745327	validation_1-error:0.206364	validation_1-auc:0.734928
# [32]	validation_0-error:0.205246	validation_0-auc:0.745712	validation_1-error:0.206353	validation_1-auc:0.73509
# [33]	validation_0-error:0.205155	validation_0-auc:0.745917	validation_1-error:0.206353	validation_1-auc:0.735178
# [34]	validation_0-error:0.205012	validation_0-auc:0.746208	validation_1-error:0.206291	validation_1-auc:0.735375
# [35]	validation_0-error:0.204921	validation_0-auc:0.746676	validation_1-error:0.206105	validation_1-auc:0.735648
# [36]	validation_0-error:0.204875	validation_0-auc:0.747076	validation_1-error:0.20595	validation_1-auc:0.735866
# [37]	validation_0-error:0.204788	validation_0-auc:0.747438	validation_1-error:0.206054	validation_1-auc:0.736099
# [38]	validation_0-error:0.204768	validation_0-auc:0.747765	validation_1-error:0.206147	validation_1-auc:0.736339
# [39]	validation_0-error:0.204691	validation_0-auc:0.74805	validation_1-error:0.205971	validation_1-auc:0.736521
# [40]	validation_0-error:0.204579	validation_0-auc:0.748413	validation_1-error:0.205919	validation_1-auc:0.736762
# [41]	validation_0-error:0.204584	validation_0-auc:0.748744	validation_1-error:0.205836	validation_1-auc:0.736962
# [42]	validation_0-error:0.204605	validation_0-auc:0.749003	validation_1-error:0.205795	validation_1-auc:0.737046
# [43]	validation_0-error:0.204457	validation_0-auc:0.749328	validation_1-error:0.205836	validation_1-auc:0.737233
# [44]	validation_0-error:0.204493	validation_0-auc:0.749633	validation_1-error:0.205816	validation_1-auc:0.737395
# [45]	validation_0-error:0.204355	validation_0-auc:0.749896	validation_1-error:0.205805	validation_1-auc:0.737525
# [46]	validation_0-error:0.204289	validation_0-auc:0.750233	validation_1-error:0.205785	validation_1-auc:0.737744
# [47]	validation_0-error:0.204075	validation_0-auc:0.750534	validation_1-error:0.205774	validation_1-auc:0.737849
# [48]	validation_0-error:0.203897	validation_0-auc:0.750856	validation_1-error:0.205671	validation_1-auc:0.738042
# [49]	validation_0-error:0.203867	validation_0-auc:0.751126	validation_1-error:0.205712	validation_1-auc:0.738208
# [50]	validation_0-error:0.203795	validation_0-auc:0.751502	validation_1-error:0.205702	validation_1-auc:0.738413
# [51]	validation_0-error:0.203714	validation_0-auc:0.751802	validation_1-error:0.205495	validation_1-auc:0.738558
# [52]	validation_0-error:0.203704	validation_0-auc:0.752027	validation_1-error:0.205444	validation_1-auc:0.738647
# [53]	validation_0-error:0.203693	validation_0-auc:0.752231	validation_1-error:0.205309	validation_1-auc:0.738759
# [54]	validation_0-error:0.203459	validation_0-auc:0.75256	validation_1-error:0.205392	validation_1-auc:0.738953
# [55]	validation_0-error:0.203413	validation_0-auc:0.752898	validation_1-error:0.205185	validation_1-auc:0.739143
# [56]	validation_0-error:0.203245	validation_0-auc:0.753223	validation_1-error:0.205154	validation_1-auc:0.739286
# [57]	validation_0-error:0.203133	validation_0-auc:0.753503	validation_1-error:0.205185	validation_1-auc:0.739422
# [58]	validation_0-error:0.203103	validation_0-auc:0.753848	validation_1-error:0.205382	validation_1-auc:0.73958
# [59]	validation_0-error:0.203072	validation_0-auc:0.754114	validation_1-error:0.20533	validation_1-auc:0.739707
# [60]	validation_0-error:0.202991	validation_0-auc:0.754399	validation_1-error:0.205402	validation_1-auc:0.739841
# [61]	validation_0-error:0.202894	validation_0-auc:0.754706	validation_1-error:0.205361	validation_1-auc:0.739987
# [62]	validation_0-error:0.202843	validation_0-auc:0.754968	validation_1-error:0.20532	validation_1-auc:0.740158
# [63]	validation_0-error:0.202874	validation_0-auc:0.755238	validation_1-error:0.205392	validation_1-auc:0.740301
# [64]	validation_0-error:0.202884	validation_0-auc:0.755506	validation_1-error:0.205444	validation_1-auc:0.740416
# [65]	validation_0-error:0.202762	validation_0-auc:0.755786	validation_1-error:0.205402	validation_1-auc:0.740488
# [66]	validation_0-error:0.202741	validation_0-auc:0.756035	validation_1-error:0.205258	validation_1-auc:0.74063
# [67]	validation_0-error:0.202726	validation_0-auc:0.756279	validation_1-error:0.20533	validation_1-auc:0.740691
# [68]	validation_0-error:0.202619	validation_0-auc:0.756506	validation_1-error:0.205382	validation_1-auc:0.740799
# [69]	validation_0-error:0.202634	validation_0-auc:0.756731	validation_1-error:0.20534	validation_1-auc:0.740892
# [70]	validation_0-error:0.202619	validation_0-auc:0.757002	validation_1-error:0.20534	validation_1-auc:0.741
# [71]	validation_0-error:0.202695	validation_0-auc:0.757286	validation_1-error:0.20532	validation_1-auc:0.741087
# [72]	validation_0-error:0.202675	validation_0-auc:0.757598	validation_1-error:0.205289	validation_1-auc:0.741177
# [73]	validation_0-error:0.202655	validation_0-auc:0.757828	validation_1-error:0.205392	validation_1-auc:0.741294
# [74]	validation_0-error:0.20268	validation_0-auc:0.758005	validation_1-error:0.205382	validation_1-auc:0.741357
# [75]	validation_0-error:0.202512	validation_0-auc:0.758276	validation_1-error:0.20534	validation_1-auc:0.741445
# [76]	validation_0-error:0.202415	validation_0-auc:0.758532	validation_1-error:0.20532	validation_1-auc:0.741536
# [77]	validation_0-error:0.202268	validation_0-auc:0.758731	validation_1-error:0.205227	validation_1-auc:0.741589
# [78]	validation_0-error:0.202212	validation_0-auc:0.758942	validation_1-error:0.205299	validation_1-auc:0.741656
# [79]	validation_0-error:0.202146	validation_0-auc:0.759173	validation_1-error:0.205227	validation_1-auc:0.741732
# [80]	validation_0-error:0.202095	validation_0-auc:0.75943	validation_1-error:0.20534	validation_1-auc:0.741807
# [81]	validation_0-error:0.201978	validation_0-auc:0.759696	validation_1-error:0.205278	validation_1-auc:0.741886
# [82]	validation_0-error:0.201835	validation_0-auc:0.760012	validation_1-error:0.205258	validation_1-auc:0.741996
# [83]	validation_0-error:0.201937	validation_0-auc:0.760252	validation_1-error:0.205165	validation_1-auc:0.742075
# [84]	validation_0-error:0.201774	validation_0-auc:0.760354	validation_1-error:0.205165	validation_1-auc:0.74213
# [85]	validation_0-error:0.201708	validation_0-auc:0.760568	validation_1-error:0.205113	validation_1-auc:0.742157
# [86]	validation_0-error:0.201682	validation_0-auc:0.760826	validation_1-error:0.205009	validation_1-auc:0.742242
# [87]	validation_0-error:0.201596	validation_0-auc:0.761024	validation_1-error:0.205113	validation_1-auc:0.742299
# [88]	validation_0-error:0.20158	validation_0-auc:0.761293	validation_1-error:0.205113	validation_1-auc:0.74239
# [89]	validation_0-error:0.201519	validation_0-auc:0.761486	validation_1-error:0.205113	validation_1-auc:0.742445
# [90]	validation_0-error:0.201468	validation_0-auc:0.761816	validation_1-error:0.205071	validation_1-auc:0.742591
# [91]	validation_0-error:0.201361	validation_0-auc:0.762077	validation_1-error:0.20503	validation_1-auc:0.742687
# [92]	validation_0-error:0.201336	validation_0-auc:0.76216	validation_1-error:0.20502	validation_1-auc:0.742732
# [93]	validation_0-error:0.201321	validation_0-auc:0.762394	validation_1-error:0.204937	validation_1-auc:0.742774
# [94]	validation_0-error:0.20128	validation_0-auc:0.762659	validation_1-error:0.204927	validation_1-auc:0.742849
# [95]	validation_0-error:0.201209	validation_0-auc:0.762855	validation_1-error:0.204937	validation_1-auc:0.742887
# [96]	validation_0-error:0.201066	validation_0-auc:0.763049	validation_1-error:0.204958	validation_1-auc:0.74293
# [97]	validation_0-error:0.201112	validation_0-auc:0.763252	validation_1-error:0.205092	validation_1-auc:0.743003
# [98]	validation_0-error:0.201025	validation_0-auc:0.76348	validation_1-error:0.205082	validation_1-auc:0.743062
# [99]	validation_0-error:0.201087	validation_0-auc:0.763643	validation_1-error:0.205061	validation_1-auc:0.743058
# [100]	validation_0-error:0.200944	validation_0-auc:0.763856	validation_1-error:0.205113	validation_1-auc:0.743089
# [101]	validation_0-error:0.200903	validation_0-auc:0.76395	validation_1-error:0.205165	validation_1-auc:0.743094
# [102]	validation_0-error:0.200847	validation_0-auc:0.764222	validation_1-error:0.205154	validation_1-auc:0.743203
# [103]	validation_0-error:0.200827	validation_0-auc:0.764459	validation_1-error:0.205268	validation_1-auc:0.743252
# [104]	validation_0-error:0.200761	validation_0-auc:0.764661	validation_1-error:0.205216	validation_1-auc:0.74329
# [105]	validation_0-error:0.20073	validation_0-auc:0.76487	validation_1-error:0.205196	validation_1-auc:0.743319
# [106]	validation_0-error:0.200633	validation_0-auc:0.765066	validation_1-error:0.205154	validation_1-auc:0.743407
# [107]	validation_0-error:0.200664	validation_0-auc:0.765179	validation_1-error:0.205144	validation_1-auc:0.743429
# [108]	validation_0-error:0.200552	validation_0-auc:0.765464	validation_1-error:0.204999	validation_1-auc:0.743531
# [109]	validation_0-error:0.200577	validation_0-auc:0.765604	validation_1-error:0.204927	validation_1-auc:0.74357
# [110]	validation_0-error:0.200516	validation_0-auc:0.765659	validation_1-error:0.204958	validation_1-auc:0.743578
# [111]	validation_0-error:0.200348	validation_0-auc:0.765903	validation_1-error:0.204947	validation_1-auc:0.743657
# [112]	validation_0-error:0.200302	validation_0-auc:0.766102	validation_1-error:0.205051	validation_1-auc:0.743715
# [113]	validation_0-error:0.200206	validation_0-auc:0.766288	validation_1-error:0.20502	validation_1-auc:0.743784
# [114]	validation_0-error:0.200231	validation_0-auc:0.766539	validation_1-error:0.205009	validation_1-auc:0.743913
# [115]	validation_0-error:0.20015	validation_0-auc:0.766784	validation_1-error:0.204927	validation_1-auc:0.743935
# [116]	validation_0-error:0.200134	validation_0-auc:0.766955	validation_1-error:0.204927	validation_1-auc:0.743986
# [117]	validation_0-error:0.200099	validation_0-auc:0.767203	validation_1-error:0.20473	validation_1-auc:0.744009
# [118]	validation_0-error:0.199982	validation_0-auc:0.767334	validation_1-error:0.204803	validation_1-auc:0.744047
# [119]	validation_0-error:0.199966	validation_0-auc:0.767507	validation_1-error:0.204844	validation_1-auc:0.744086
# [120]	validation_0-error:0.199875	validation_0-auc:0.767577	validation_1-error:0.204906	validation_1-auc:0.74408
# [121]	validation_0-error:0.199859	validation_0-auc:0.767699	validation_1-error:0.204803	validation_1-auc:0.744096
# [122]	validation_0-error:0.1999	validation_0-auc:0.767841	validation_1-error:0.204844	validation_1-auc:0.744132
# [123]	validation_0-error:0.199875	validation_0-auc:0.768	validation_1-error:0.204896	validation_1-auc:0.744157
# [124]	validation_0-error:0.199849	validation_0-auc:0.768199	validation_1-error:0.204885	validation_1-auc:0.744206
# [125]	validation_0-error:0.199844	validation_0-auc:0.768381	validation_1-error:0.204927	validation_1-auc:0.744211
# [126]	validation_0-error:0.199722	validation_0-auc:0.768503	validation_1-error:0.204947	validation_1-auc:0.744263
# [127]	validation_0-error:0.199686	validation_0-auc:0.768649	validation_1-error:0.204958	validation_1-auc:0.744283
# [128]	validation_0-error:0.199564	validation_0-auc:0.768859	validation_1-error:0.204937	validation_1-auc:0.744359
# [129]	validation_0-error:0.199518	validation_0-auc:0.769003	validation_1-error:0.204947	validation_1-auc:0.744395
# [130]	validation_0-error:0.199452	validation_0-auc:0.769093	validation_1-error:0.20502	validation_1-auc:0.744401
# [131]	validation_0-error:0.199371	validation_0-auc:0.769276	validation_1-error:0.204927	validation_1-auc:0.744434
# [132]	validation_0-error:0.199355	validation_0-auc:0.769443	validation_1-error:0.204906	validation_1-auc:0.744412
# [133]	validation_0-error:0.199243	validation_0-auc:0.769565	validation_1-error:0.204916	validation_1-auc:0.744438
# [134]	validation_0-error:0.199223	validation_0-auc:0.769624	validation_1-error:0.204927	validation_1-auc:0.74444
# [135]	validation_0-error:0.199218	validation_0-auc:0.769825	validation_1-error:0.204865	validation_1-auc:0.744455
# [136]	validation_0-error:0.199192	validation_0-auc:0.770053	validation_1-error:0.204834	validation_1-auc:0.744489
# [137]	validation_0-error:0.199243	validation_0-auc:0.770218	validation_1-error:0.204803	validation_1-auc:0.744513
# [138]	validation_0-error:0.199228	validation_0-auc:0.770313	validation_1-error:0.204844	validation_1-auc:0.744525
# [139]	validation_0-error:0.199152	validation_0-auc:0.770428	validation_1-error:0.204916	validation_1-auc:0.744541
# [140]	validation_0-error:0.199126	validation_0-auc:0.770637	validation_1-error:0.204896	validation_1-auc:0.744631
# [141]	validation_0-error:0.199121	validation_0-auc:0.770798	validation_1-error:0.204844	validation_1-auc:0.744658
# [142]	validation_0-error:0.199055	validation_0-auc:0.770925	validation_1-error:0.204772	validation_1-auc:0.744685
# [143]	validation_0-error:0.198923	validation_0-auc:0.771098	validation_1-error:0.20471	validation_1-auc:0.74474
# [144]	validation_0-error:0.198958	validation_0-auc:0.771254	validation_1-error:0.20472	validation_1-auc:0.744746
# [145]	validation_0-error:0.198953	validation_0-auc:0.771345	validation_1-error:0.204648	validation_1-auc:0.744772
# [146]	validation_0-error:0.198826	validation_0-auc:0.771478	validation_1-error:0.204658	validation_1-auc:0.744808
# [147]	validation_0-error:0.19877	validation_0-auc:0.771524	validation_1-error:0.204627	validation_1-auc:0.744818
# [148]	validation_0-error:0.198688	validation_0-auc:0.771662	validation_1-error:0.204627	validation_1-auc:0.744842
# [149]	validation_0-error:0.198643	validation_0-auc:0.771734	validation_1-error:0.204627	validation_1-auc:0.744877
# [150]	validation_0-error:0.198622	validation_0-auc:0.771848	validation_1-error:0.204596	validation_1-auc:0.744883
# [151]	validation_0-error:0.198622	validation_0-auc:0.77189	validation_1-error:0.204596	validation_1-auc:0.744873
# [152]	validation_0-error:0.1985	validation_0-auc:0.772039	validation_1-error:0.204606	validation_1-auc:0.74489
# [153]	validation_0-error:0.198434	validation_0-auc:0.772239	validation_1-error:0.204658	validation_1-auc:0.744947
# [154]	validation_0-error:0.198403	validation_0-auc:0.772364	validation_1-error:0.204617	validation_1-auc:0.744972
# [155]	validation_0-error:0.198363	validation_0-auc:0.772523	validation_1-error:0.204596	validation_1-auc:0.744976
# [156]	validation_0-error:0.198352	validation_0-auc:0.772618	validation_1-error:0.204544	validation_1-auc:0.744985
# [157]	validation_0-error:0.198378	validation_0-auc:0.77274	validation_1-error:0.204606	validation_1-auc:0.745048
# [158]	validation_0-error:0.198291	validation_0-auc:0.772808	validation_1-error:0.204596	validation_1-auc:0.745083
# [159]	validation_0-error:0.198307	validation_0-auc:0.772982	validation_1-error:0.204544	validation_1-auc:0.745095
# [160]	validation_0-error:0.198312	validation_0-auc:0.773113	validation_1-error:0.204586	validation_1-auc:0.745134
# [161]	validation_0-error:0.19824	validation_0-auc:0.77322	validation_1-error:0.204627	validation_1-auc:0.745149
# [162]	validation_0-error:0.19821	validation_0-auc:0.773308	validation_1-error:0.204648	validation_1-auc:0.745173
# [163]	validation_0-error:0.198159	validation_0-auc:0.773442	validation_1-error:0.204637	validation_1-auc:0.745167
# [164]	validation_0-error:0.198016	validation_0-auc:0.773638	validation_1-error:0.204606	validation_1-auc:0.745197
# [165]	validation_0-error:0.197996	validation_0-auc:0.773674	validation_1-error:0.204679	validation_1-auc:0.745187
# [166]	validation_0-error:0.197996	validation_0-auc:0.773788	validation_1-error:0.20471	validation_1-auc:0.745212
# [167]	validation_0-error:0.19796	validation_0-auc:0.773935	validation_1-error:0.204751	validation_1-auc:0.74522
# [168]	validation_0-error:0.19797	validation_0-auc:0.774017	validation_1-error:0.204813	validation_1-auc:0.745259
# [169]	validation_0-error:0.19793	validation_0-auc:0.774111	validation_1-error:0.204658	validation_1-auc:0.745305
# [170]	validation_0-error:0.197914	validation_0-auc:0.77417	validation_1-error:0.204689	validation_1-auc:0.745313
# [171]	validation_0-error:0.197823	validation_0-auc:0.77431	validation_1-error:0.20472	validation_1-auc:0.745327
# [172]	validation_0-error:0.197762	validation_0-auc:0.774507	validation_1-error:0.204648	validation_1-auc:0.74536
# [173]	validation_0-error:0.197772	validation_0-auc:0.77465	validation_1-error:0.204472	validation_1-auc:0.745382
# [174]	validation_0-error:0.197787	validation_0-auc:0.774796	validation_1-error:0.204555	validation_1-auc:0.745415
# [175]	validation_0-error:0.197757	validation_0-auc:0.774923	validation_1-error:0.204565	validation_1-auc:0.745435
# [176]	validation_0-error:0.197752	validation_0-auc:0.775017	validation_1-error:0.204575	validation_1-auc:0.745458
# [177]	validation_0-error:0.19765	validation_0-auc:0.775127	validation_1-error:0.204555	validation_1-auc:0.745453
# [178]	validation_0-error:0.19769	validation_0-auc:0.775243	validation_1-error:0.204472	validation_1-auc:0.745487
# [179]	validation_0-error:0.197614	validation_0-auc:0.775336	validation_1-error:0.204627	validation_1-auc:0.745491
# [180]	validation_0-error:0.197584	validation_0-auc:0.775386	validation_1-error:0.204586	validation_1-auc:0.745522
# [181]	validation_0-error:0.197629	validation_0-auc:0.775519	validation_1-error:0.204586	validation_1-auc:0.745525
# [182]	validation_0-error:0.197604	validation_0-auc:0.775578	validation_1-error:0.204575	validation_1-auc:0.745525
# [183]	validation_0-error:0.197584	validation_0-auc:0.775665	validation_1-error:0.204637	validation_1-auc:0.745535
# [184]	validation_0-error:0.197522	validation_0-auc:0.775786	validation_1-error:0.204596	validation_1-auc:0.745561
# [185]	validation_0-error:0.197522	validation_0-auc:0.775899	validation_1-error:0.204575	validation_1-auc:0.745556
# [186]	validation_0-error:0.197472	validation_0-auc:0.775981	validation_1-error:0.204513	validation_1-auc:0.745555
# [187]	validation_0-error:0.197492	validation_0-auc:0.77618	validation_1-error:0.204524	validation_1-auc:0.745606
# [188]	validation_0-error:0.197482	validation_0-auc:0.776297	validation_1-error:0.204482	validation_1-auc:0.745613
# [189]	validation_0-error:0.197482	validation_0-auc:0.776345	validation_1-error:0.204503	validation_1-auc:0.745627
# [190]	validation_0-error:0.197456	validation_0-auc:0.776401	validation_1-error:0.204503	validation_1-auc:0.745612
# [191]	validation_0-error:0.197436	validation_0-auc:0.776476	validation_1-error:0.204441	validation_1-auc:0.745618
# [192]	validation_0-error:0.197304	validation_0-auc:0.776685	validation_1-error:0.204389	validation_1-auc:0.745645
# [193]	validation_0-error:0.197278	validation_0-auc:0.776803	validation_1-error:0.204389	validation_1-auc:0.745666
# [194]	validation_0-error:0.197268	validation_0-auc:0.776889	validation_1-error:0.204348	validation_1-auc:0.745681
# [195]	validation_0-error:0.197334	validation_0-auc:0.776949	validation_1-error:0.204379	validation_1-auc:0.745685
# [196]	validation_0-error:0.197314	validation_0-auc:0.777051	validation_1-error:0.204369	validation_1-auc:0.745685
# [197]	validation_0-error:0.197288	validation_0-auc:0.777115	validation_1-error:0.204358	validation_1-auc:0.7457
# [198]	validation_0-error:0.197253	validation_0-auc:0.777269	validation_1-error:0.204317	validation_1-auc:0.745696
# [199]	validation_0-error:0.197237	validation_0-auc:0.777395	validation_1-error:0.204296	validation_1-auc:0.745703
# [200]	validation_0-error:0.197212	validation_0-auc:0.777548	validation_1-error:0.204265	validation_1-auc:0.745722
# [201]	validation_0-error:0.197125	validation_0-auc:0.777614	validation_1-error:0.204286	validation_1-auc:0.74574
# [202]	validation_0-error:0.197151	validation_0-auc:0.777761	validation_1-error:0.2041	validation_1-auc:0.745752
# [203]	validation_0-error:0.196998	validation_0-auc:0.777858	validation_1-error:0.204244	validation_1-auc:0.745772
# [204]	validation_0-error:0.197044	validation_0-auc:0.777927	validation_1-error:0.204255	validation_1-auc:0.745796
# [205]	validation_0-error:0.196901	validation_0-auc:0.778038	validation_1-error:0.204327	validation_1-auc:0.745809
# [206]	validation_0-error:0.196886	validation_0-auc:0.778207	validation_1-error:0.204265	validation_1-auc:0.74581
# [207]	validation_0-error:0.196886	validation_0-auc:0.778347	validation_1-error:0.204317	validation_1-auc:0.745833
# [208]	validation_0-error:0.196886	validation_0-auc:0.778522	validation_1-error:0.204327	validation_1-auc:0.745859
# [209]	validation_0-error:0.196779	validation_0-auc:0.778618	validation_1-error:0.20441	validation_1-auc:0.745864
# [210]	validation_0-error:0.196764	validation_0-auc:0.778645	validation_1-error:0.204462	validation_1-auc:0.745861
# [211]	validation_0-error:0.196769	validation_0-auc:0.778715	validation_1-error:0.204451	validation_1-auc:0.745859
# [212]	validation_0-error:0.196728	validation_0-auc:0.778842	validation_1-error:0.204389	validation_1-auc:0.745866
# [213]	validation_0-error:0.196698	validation_0-auc:0.778965	validation_1-error:0.20442	validation_1-auc:0.745855
# [214]	validation_0-error:0.196631	validation_0-auc:0.779179	validation_1-error:0.204617	validation_1-auc:0.745882
# [215]	validation_0-error:0.196621	validation_0-auc:0.779236	validation_1-error:0.204627	validation_1-auc:0.74588
# [216]	validation_0-error:0.19656	validation_0-auc:0.779357	validation_1-error:0.204586	validation_1-auc:0.745907
# [217]	validation_0-error:0.196591	validation_0-auc:0.779464	validation_1-error:0.204648	validation_1-auc:0.745908
# [218]	validation_0-error:0.196509	validation_0-auc:0.779543	validation_1-error:0.204637	validation_1-auc:0.745914
# [219]	validation_0-error:0.19654	validation_0-auc:0.779601	validation_1-error:0.204668	validation_1-auc:0.745917
# [220]	validation_0-error:0.19654	validation_0-auc:0.779657	validation_1-error:0.204679	validation_1-auc:0.745923
# [221]	validation_0-error:0.196575	validation_0-auc:0.779741	validation_1-error:0.204565	validation_1-auc:0.745939
# [222]	validation_0-error:0.196468	validation_0-auc:0.779889	validation_1-error:0.204493	validation_1-auc:0.745952
# [223]	validation_0-error:0.196443	validation_0-auc:0.779987	validation_1-error:0.204524	validation_1-auc:0.745972
# [224]	validation_0-error:0.196336	validation_0-auc:0.780087	validation_1-error:0.204524	validation_1-auc:0.745984
# [225]	validation_0-error:0.196311	validation_0-auc:0.780203	validation_1-error:0.204441	validation_1-auc:0.74601
# [226]	validation_0-error:0.19628	validation_0-auc:0.780309	validation_1-error:0.204462	validation_1-auc:0.746022
# [227]	validation_0-error:0.196285	validation_0-auc:0.780449	validation_1-error:0.204513	validation_1-auc:0.746028
# [228]	validation_0-error:0.196275	validation_0-auc:0.780542	validation_1-error:0.204565	validation_1-auc:0.746025
# [229]	validation_0-error:0.196265	validation_0-auc:0.780616	validation_1-error:0.204565	validation_1-auc:0.746017
# [230]	validation_0-error:0.196132	validation_0-auc:0.780752	validation_1-error:0.204586	validation_1-auc:0.74602
# [231]	validation_0-error:0.196076	validation_0-auc:0.780886	validation_1-error:0.204741	validation_1-auc:0.746017
# [232]	validation_0-error:0.19599	validation_0-auc:0.781003	validation_1-error:0.204751	validation_1-auc:0.74603
# [233]	validation_0-error:0.195954	validation_0-auc:0.781133	validation_1-error:0.204761	validation_1-auc:0.746068
# [234]	validation_0-error:0.196015	validation_0-auc:0.781269	validation_1-error:0.20472	validation_1-auc:0.746071
# [235]	validation_0-error:0.195954	validation_0-auc:0.781376	validation_1-error:0.204668	validation_1-auc:0.746087
# [236]	validation_0-error:0.195934	validation_0-auc:0.781551	validation_1-error:0.204637	validation_1-auc:0.746094
# [237]	validation_0-error:0.195847	validation_0-auc:0.781677	validation_1-error:0.204596	validation_1-auc:0.746102
# [238]	validation_0-error:0.195842	validation_0-auc:0.781704	validation_1-error:0.204627	validation_1-auc:0.746094
# [239]	validation_0-error:0.195812	validation_0-auc:0.781851	validation_1-error:0.204792	validation_1-auc:0.746095
# [240]	validation_0-error:0.195761	validation_0-auc:0.782021	validation_1-error:0.204803	validation_1-auc:0.746104
# [241]	validation_0-error:0.195695	validation_0-auc:0.78217	validation_1-error:0.204699	validation_1-auc:0.746122
# [242]	validation_0-error:0.195705	validation_0-auc:0.782214	validation_1-error:0.20473	validation_1-auc:0.746132
# [243]	validation_0-error:0.195684	validation_0-auc:0.78223	validation_1-error:0.20472	validation_1-auc:0.746126
# [244]	validation_0-error:0.195674	validation_0-auc:0.782309	validation_1-error:0.20472	validation_1-auc:0.746121
# [245]	validation_0-error:0.195633	validation_0-auc:0.782436	validation_1-error:0.20473	validation_1-auc:0.746108
# [246]	validation_0-error:0.195618	validation_0-auc:0.78248	validation_1-error:0.204772	validation_1-auc:0.746114
# [247]	validation_0-error:0.195598	validation_0-auc:0.782562	validation_1-error:0.204792	validation_1-auc:0.746149
# [248]	validation_0-error:0.195593	validation_0-auc:0.782705	validation_1-error:0.204834	validation_1-auc:0.746131
# [249]	validation_0-error:0.195628	validation_0-auc:0.782865	validation_1-error:0.204772	validation_1-auc:0.746156
# [250]	validation_0-error:0.195598	validation_0-auc:0.78294	validation_1-error:0.204751	validation_1-auc:0.746147
# [251]	validation_0-error:0.195532	validation_0-auc:0.783072	validation_1-error:0.204772	validation_1-auc:0.746186
# [252]	validation_0-error:0.195384	validation_0-auc:0.783185	validation_1-error:0.204761	validation_1-auc:0.746185
# [253]	validation_0-error:0.195303	validation_0-auc:0.783327	validation_1-error:0.204823	validation_1-auc:0.746201
# [254]	validation_0-error:0.195308	validation_0-auc:0.783422	validation_1-error:0.204803	validation_1-auc:0.746191
# [255]	validation_0-error:0.195287	validation_0-auc:0.783485	validation_1-error:0.204792	validation_1-auc:0.746206
# [256]	validation_0-error:0.195287	validation_0-auc:0.78351	validation_1-error:0.204782	validation_1-auc:0.746199
# [257]	validation_0-error:0.195272	validation_0-auc:0.783596	validation_1-error:0.204823	validation_1-auc:0.746226
# [258]	validation_0-error:0.195282	validation_0-auc:0.783713	validation_1-error:0.204792	validation_1-auc:0.746219
# [259]	validation_0-error:0.195231	validation_0-auc:0.783858	validation_1-error:0.204782	validation_1-auc:0.746225
# [260]	validation_0-error:0.195247	validation_0-auc:0.783894	validation_1-error:0.204834	validation_1-auc:0.746227
# [261]	validation_0-error:0.195196	validation_0-auc:0.783959	validation_1-error:0.204865	validation_1-auc:0.746248
# [262]	validation_0-error:0.195185	validation_0-auc:0.784093	validation_1-error:0.204896	validation_1-auc:0.746247
# [263]	validation_0-error:0.195196	validation_0-auc:0.784231	validation_1-error:0.204875	validation_1-auc:0.746231
# [264]	validation_0-error:0.195185	validation_0-auc:0.784318	validation_1-error:0.204834	validation_1-auc:0.746241
# [265]	validation_0-error:0.195134	validation_0-auc:0.784365	validation_1-error:0.204834	validation_1-auc:0.746238
# [266]	validation_0-error:0.195109	validation_0-auc:0.784504	validation_1-error:0.204927	validation_1-auc:0.746267
# [267]	validation_0-error:0.195094	validation_0-auc:0.784558	validation_1-error:0.204927	validation_1-auc:0.746265
# [268]	validation_0-error:0.195073	validation_0-auc:0.784687	validation_1-error:0.204792	validation_1-auc:0.746272
# [269]	validation_0-error:0.195058	validation_0-auc:0.784816	validation_1-error:0.204916	validation_1-auc:0.746276
# [270]	validation_0-error:0.194997	validation_0-auc:0.784981	validation_1-error:0.204927	validation_1-auc:0.746275
# [271]	validation_0-error:0.194936	validation_0-auc:0.785067	validation_1-error:0.204947	validation_1-auc:0.746279
# [272]	validation_0-error:0.194941	validation_0-auc:0.785148	validation_1-error:0.204927	validation_1-auc:0.746271
# [273]	validation_0-error:0.194905	validation_0-auc:0.785255	validation_1-error:0.204896	validation_1-auc:0.746259
# [274]	validation_0-error:0.19489	validation_0-auc:0.785383	validation_1-error:0.204885	validation_1-auc:0.74628
# [275]	validation_0-error:0.194854	validation_0-auc:0.7854	validation_1-error:0.204896	validation_1-auc:0.746273
# [276]	validation_0-error:0.194865	validation_0-auc:0.785524	validation_1-error:0.204896	validation_1-auc:0.746288
# [277]	validation_0-error:0.194824	validation_0-auc:0.785655	validation_1-error:0.204741	validation_1-auc:0.746312
# [278]	validation_0-error:0.194788	validation_0-auc:0.785749	validation_1-error:0.204751	validation_1-auc:0.74631
# [279]	validation_0-error:0.194778	validation_0-auc:0.785811	validation_1-error:0.20473	validation_1-auc:0.746302
# [280]	validation_0-error:0.194753	validation_0-auc:0.785961	validation_1-error:0.204803	validation_1-auc:0.746309
# [281]	validation_0-error:0.194758	validation_0-auc:0.786009	validation_1-error:0.204751	validation_1-auc:0.746319
# [282]	validation_0-error:0.194707	validation_0-auc:0.786092	validation_1-error:0.204751	validation_1-auc:0.746319
# [283]	validation_0-error:0.194697	validation_0-auc:0.786124	validation_1-error:0.20472	validation_1-auc:0.746322
# [284]	validation_0-error:0.194686	validation_0-auc:0.786175	validation_1-error:0.20473	validation_1-auc:0.746318
# [285]	validation_0-error:0.194692	validation_0-auc:0.786252	validation_1-error:0.20471	validation_1-auc:0.746304
# [286]	validation_0-error:0.1946	validation_0-auc:0.786411	validation_1-error:0.20471	validation_1-auc:0.746308
# [287]	validation_0-error:0.194544	validation_0-auc:0.786578	validation_1-error:0.204772	validation_1-auc:0.746313
# [288]	validation_0-error:0.194544	validation_0-auc:0.786681	validation_1-error:0.204761	validation_1-auc:0.746332
# [289]	validation_0-error:0.194549	validation_0-auc:0.786726	validation_1-error:0.204772	validation_1-auc:0.74632
# [290]	validation_0-error:0.194554	validation_0-auc:0.786821	validation_1-error:0.204792	validation_1-auc:0.746328
# [291]	validation_0-error:0.194554	validation_0-auc:0.78683	validation_1-error:0.204782	validation_1-auc:0.746326
# [292]	validation_0-error:0.194534	validation_0-auc:0.786946	validation_1-error:0.204823	validation_1-auc:0.746326
# [293]	validation_0-error:0.194518	validation_0-auc:0.787018	validation_1-error:0.204823	validation_1-auc:0.746351
# [294]	validation_0-error:0.194523	validation_0-auc:0.787123	validation_1-error:0.204834	validation_1-auc:0.746373
# [295]	validation_0-error:0.194493	validation_0-auc:0.787177	validation_1-error:0.204834	validation_1-auc:0.74637
# [296]	validation_0-error:0.194452	validation_0-auc:0.787269	validation_1-error:0.204823	validation_1-auc:0.746364
# [297]	validation_0-error:0.194396	validation_0-auc:0.787387	validation_1-error:0.204834	validation_1-auc:0.746358
# [298]	validation_0-error:0.194406	validation_0-auc:0.787406	validation_1-error:0.204813	validation_1-auc:0.746358
# [299]	validation_0-error:0.19435	validation_0-auc:0.787519	validation_1-error:0.204854	validation_1-auc:0.746359
# [300]	validation_0-error:0.194355	validation_0-auc:0.787599	validation_1-error:0.204844	validation_1-auc:0.746362
# [301]	validation_0-error:0.194355	validation_0-auc:0.787669	validation_1-error:0.204813	validation_1-auc:0.746364
# [302]	validation_0-error:0.194259	validation_0-auc:0.787811	validation_1-error:0.204751	validation_1-auc:0.746368
# [303]	validation_0-error:0.194254	validation_0-auc:0.787894	validation_1-error:0.204782	validation_1-auc:0.746366
# [304]	validation_0-error:0.194162	validation_0-auc:0.788028	validation_1-error:0.204772	validation_1-auc:0.746358
# Stopping. Best iteration:
# [294]	validation_0-error:0.194523	validation_0-auc:0.787123	validation_1-error:0.204834	validation_1-auc:0.746373
#
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=0.6,
#        colsample_bytree=0.8, gamma=0.01, learning_rate=0.07,
#        max_delta_step=3, max_depth=6, max_features='sqrt',
#        min_child_weight=8, missing=None, n_estimators=1900, n_jobs=3,
#        nthread=None, objective='binary:logistic', random_state=10,
#        reg_alpha=0.1, reg_lambda=2.5, scale_pos_weight=1, seed=800,
#        silent=True, subsample=0.99)

# %%
evaluation_1(test_y, predictions,feature_columns, model)
# Out:
#              precision    recall  f1-score   support
#
#           0       0.81      0.97      0.88     75716
#           1       0.60      0.18      0.27     21021
#
# avg / total       0.76      0.80      0.75     96737
#
#
#                            importance
# feature
# Point                           0.078
# PAR_REUSSITE_3P                 0.059
# NOM_JOC                         0.058
# PAR_CARRIERE                    0.056
# PAR_PROPRIO                     0.053
# NOM_ENTR                        0.052
# PAR_RUESSITE_PLACE              0.047
# PAR_JOC_NB_COURSE               0.046
# PAR_REUSSITE_GAGNE              0.042
# PAR_AGE                         0.039
# PAR_ENT_VICTOIRE                0.038
# PAR_NUM                         0.037
# Nb_partant                      0.037
# PAR_ENT_RAPPORT_GAGNANT_M       0.037
# PAR_JOC_REU_PLACE               0.035
# PAR_ENT_REU_PLACE               0.033
# pAR_JOC_RAPPORT_GAGNANT_M       0.033
# PAR_JOC_PLACE_3P                0.032
# pAR_JOC_ECART_GAGNANT           0.028
# PAR_ENT_ECART_GAGNANT           0.027
# pAR_JOC_REUSSITE_GAGNE          0.025
# PAR_JOC_ECART_PLACE             0.022
# PAR_ENT_REUSSITE_GAGNE          0.020
# PAR_PLACE                       0.020
# pAR_JOC_VICTOIRE                0.018
# PAR_CARRIERE_Q                  0.016
# PAR_PLACE_Q                     0.008
# PAR_REUSSITE_QUINTE             0.007
# ----------KBEST-----------------
# PAR_AGE     314.4796798252699
# PAR_CARRIERE     6658.679101393014
# PAR_CARRIERE_Q     4822.331096789414
# PAR_ENT_ECART_GAGNANT     1468.8763010040939
# PAR_ENT_RAPPORT_GAGNANT_M     924.3695975537788
# PAR_ENT_REU_PLACE     444.07112884777007
# PAR_ENT_REUSSITE_GAGNE     287.84758508307766
# PAR_ENT_VICTOIRE     69537.41923045061
# pAR_JOC_ECART_GAGNANT     1234.0861788707775
# PAR_JOC_ECART_PLACE     836.7257697283017
# PAR_JOC_NB_COURSE     1017658.0030401652
# PAR_JOC_PLACE_3P     464889.06597615057
# pAR_JOC_RAPPORT_GAGNANT_M     321.79730620148507
# PAR_JOC_REU_PLACE     720.0774271494768
# pAR_JOC_REUSSITE_GAGNE     409.02304427905426
# pAR_JOC_VICTOIRE     202879.45368062332
# PAR_NUM     24.03365910674588
# PAR_PLACE     4107.266290495937
# PAR_PLACE_Q     1113.6237767695598
# PAR_REUSSITE_3P     1310.5013205217451
# PAR_REUSSITE_GAGNE     884.8930001427041
# PAR_REUSSITE_QUINTE     35.23407607265719
# PAR_RUESSITE_PLACE     523.5151456203077
# Point     266734.12751501804
# Nb_partant     1059.790903175744
# PAR_PROPRIO     985758.8404365978
# NOM_JOC     1421100.8804658987
# NOM_ENTR     422143.8456924309
# --------------------------

# %% [markdown]
# # CSV

# %%
construireFichierCSV(1, model, feature_columns, response_column, 0)
# Out:
# Lecture data d:\data_jour.csv
# Fin de lecture  de d:\data_jour.csv
#           0         1  0
# 0  0.752562  0.247438  0
# 1  0.778019  0.221981  0
# 2  0.901370  0.098630  0
# 3  0.712954  0.287046  0
# 4  0.960822  0.039178  0
#
#
# Test_x                        Point   v0   v1  sel
# IDPARTCIPANT IDCOURSE
# 1067302      86351       143  0.0  0.0    0
# 1067428      86359        82  0.0  0.0    0
# 1067493      86363       173  0.0  0.0    0
# 1067541      86366       210  0.0  0.0    0
#
#
#  ALLER DANS APPLICATION DIABOLO ...Allure 1
